# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# Merged and deduplicated sentences (Ground Truth)
merged_ground_truth_sentences = ['great god king', 'he king gives', 'god gives life', 'father gives life', 'mother gives birth', 'god gives power', 'great god power', 'beautiful city town', 'peace satisfy heart', 'heart love life', 'man love woman', 'woman gives life', 'god hears prayer', 'god sees people', 'people fear god', 'strong king power', 'king rules town', 'lord every thing', 'master lord people', 'servant hears master', 'old man wisdom', 'youth strength force', 'eye sees star', 'star in sky', 'sun above horizon', 'water ripple river', 'river flows town', 'riverbank field grain', 'field gives grain', 'grain gives life', 'man eats bread', 'loaf of bread', 'offering gives peace', 'temple gives peace', 'god in temple', 'house behind gate', 'gate opens town', 'road leads town', 'mountain above town', 'hill slope desert', 'desert hare lives', 'desert hill west', 'west underground dead', 'soul ba lives', 'ka spirit lives', 'life ankh gives', 'god gives ankh', 'scarab become life', 'to become god', 'king becomes god', 'throne of king', 'seat throne king', 'seated god throne', 'seated man speaks', 'mouth speaks truth', 'feather truth maat', 'heart weighs truth', 'judgment of heart', 'eye of god', 'cobra guards king', 'snake guards temple', 'fire gives power', 'storm gives fear', 'people fear storm', 'stone builds temple', 'brick builds house', 'pillar supports temple', 'stability djed power', 'strong backbone king', 'hand gives offering', 'foot walks road', 'man opens door', 'door bolt opens', 'jar holds water', 'lake holds water', 'river gives water', 'water gives life', 'plant gives life', 'lotus plant life', 'papyrus scroll writing', 'writing scribe man', 'scribe writes book', 'book holds wisdom', 'hear listen god', 'god hears voice', 'mouth eats drink', 'sweet bread offering', 'peace content satisfied', 'god gives peace', 'altar gives peace', 'god protects people', 'king protects people', 'power of king', 'strength of god', 'great mighty king', 'great god mighty', 'lord of town', 'city town people', 'people love king', 'people serve king', 'servant serves lord', 'father loves child', 'mother loves child', 'child becomes youth', 'youth becomes man', 'god emerges horizon', 'sun rises sky', 'sky holds star', 'star guides road', 'road crosses desert', 'desert surrounds town', 'town has gate', 'gate protects city', 'city holds people', 'people build house', 'house has door', 'door opens house', 'man enters house', 'woman sits stool', 'seated woman speaks', 'mouth speaks words', 'words give power', 'power strengthens king', 'king sits throne', 'throne in temple', 'temple holds god', 'god dwells temple', 'offering placed altar', 'altar in temple', 'servant brings offering', 'hand holds jar', 'jar holds milk', 'milk jar offering', 'mother feeds child', 'child drinks milk', 'father protects family', 'family lives house', 'life flows river', 'river feeds field', 'field grows plant', 'plant feeds people', 'people plow field', 'hoe tills field', 'sickle cuts grain', 'grain stored jars', 'jars in rack', 'rack in house', 'stone builds wall', 'wall guards town', 'town near river', 'river near lake', 'lake reflects sky', 'sky above earth', 'mountain touches sky', 'hill near mountain', 'hill slope path', 'path leads temple', 'pilgrims enter temple', 'god hears pilgrims', 'prayer brings peace', 'peace calms heart', 'heart seeks truth', 'truth weighs heart', 'feather measures truth', 'maat brings order', 'order brings stability', 'djed gives stability', 'stability gives power', 'power maintains order', 'king maintains order', 'law comes authority', 'authority of king', 'king wears crown', 'sedge king symbol', 'cobra crowns king', 'horned viper guards', 'snake coils rope', 'rope binds vessel', 'vessel floats water', 'water ripple moves', 'boat crosses river', 'cross marks place', 'place holds memory', 'memory lives soul', 'ba soul flies', 'bird head watches', 'eye watches horizon', 'horizon meets sky', 'west holds dead', 'underground holds soul', 'soul returns life', 'scarab renews life', 'to return west', 'old man remembers', 'youth seeks strength', 'strength builds future', 'god opens horizon', 'horizon above land', 'land holds field', 'field beside river', 'river beside town', 'town beyond gate', 'gate behind house', 'house contains family', 'family loves peace', 'peace fills heart', 'heart holds ka', 'ka joins soul', 'soul seeks west', 'west beyond horizon', 'underground holds ancestors', 'pillar grandfather ancestor', 'ancestor gives wisdom', 'wisdom guides youth', 'youth gains strength', 'strength supports backbone', 'backbone supports man', 'man walks road', 'road between towns', 'town meets city', 'city has temple', 'temple faces sky', 'sky above temple', 'star above temple', 'god beneath sky', 'god rules cosmos', 'power flows god', 'power shapes world', 'world holds people', 'people honor god', 'people bring offering', 'offering on altar', 'altar before god', 'god accepts offering', 'hand lifts loaf', 'loaf feeds people', 'people eat drink', 'mouth tastes sweet', 'sweet pleases heart', 'heart seeks peace', 'peace satisfies god', 'god grants favor', 'favor brings life', 'life fills land', 'land grows grain', 'grain fills jar', 'jar seals food', 'food feeds family', 'family honors ancestors', 'ancestors guard house', 'house near road', 'road near riverbank', 'riverbank slopes hill', 'hill near desert', 'desert beyond hill', 'desert holds silence', 'silence brings fear', 'fear respects god', 'god commands authority', 'authority guides king', 'king sits seat', 'seat inside throne', 'throne inside palace', 'palace near temple', 'temple holds writing', 'scribe knows writing', 'writing records life', 'life recorded book', 'book kept temple', 'temple preserves truth', 'heart judged maat', 'maat ensures order', 'order sustains world', 'world endures time', 'time brings change', 'change brings becoming', 'becoming creates life', 'life renews people', 'god above horizon', 'horizon above mountain', 'mountain behind town', 'town behind gate', 'gate opens house', 'house contains people', 'people fear authority', 'he king rules', 'king great mighty', 'great king power', 'power gives strength', 'strong backbone man', 'man has heart', 'heart loves truth', 'maat gives stability', 'power protects people', 'offering before god', 'temple faces horizon', 'brick builds town', 'road beside river', 'river beside riverbank', 'riverbank near field', 'life ankh god', 'ankh gives life', 'life fills people', 'people love life', 'peace satisfies heart', 'peace altar temple', 'father loves mother', 'gives birth youth', 'old man wise', 'wisdom heart old', 'storm brings fear', 'fear of god', 'cobra guards temple', 'vessel holds water', 'soul ba west', 'throne seat king', 'writing scribe records', 'book holds writing', 'truth judges heart', 'animal belly eats', 'man eats drink', 'mouth eats grain', 'grain feeds people', 'people live town', 'city town house', 'gate behind wall', 'road behind town', 'mountain behind hill', 'hill slope road', 'west holds underground', 'soul ba life', 'ka spirit life', 'life gives power', 'strength makes strong', 'strong king rules', 'he king authority', 'authority gives power', 'lord every people', 'master lord servant', 'servant does work', 'to do work', 'hand does work', 'road crosses river', 'river meets lake', 'lake water ripple', 'plant grows field', 'field plows tills', 'hoe plows field', 'sickle cuts plant', 'plant gives grain', 'grain fills vessel', 'vessel holds offering', 'god great mighty', 'great mighty power', 'people hear god', 'hear listen voice', 'eye sees face', 'face upon god', 'heart feels fear', 'fear respects authority', 'stone gives strength', 'pillar gives stability', 'backbone gives strength', 'hand gives life', 'to become strong', 'man becomes father', 'father becomes old man', 'old man venerated', 'venerated marrow strength', 'writing scribe book', 'papyrus scroll book', 'senet board game', 'people play senet board', 'temple house god', 'throne seat god', 'seated man listens', 'owl sees night', 'star lights sky', 'sky above town', 'horizon above sky', 'god face upon', 'face upon temple', 'temple face upon', 'eye face upon', 'man face upon', 'woman face upon', 'king face upon', 'god behind gate', 'house behind town', 'town behind city', 'city behind river', 'river behind riverbank', 'riverbank behind field', 'field behind hill', 'hill behind mountain', 'town above river', 'river above lake', 'lake above underground', 'underground west soul', 'west soul ba', 'soul ba god', 'ka spirit god', 'god ka spirit', 'life ankh ka', 'ankh life god', 'power strength force', 'strength force king', 'king strong backbone', 'backbone side rib', 'side rib man', 'hand forearm man', 'foot road town', 'road town city', 'city people man', 'people seated man', 'mouth eat drink speak', 'hear listen people', 'people hear king', 'king hears people', 'eye sees god', 'god sees heart', 'heart fear god', 'fear god authority', 'authority lord every', 'master lord all', 'servant seated man', 'servant do work', 'to do make', 'to give offering', 'offering peace altar', 'altar temple god', 'temple god deity', 'god deity great', 'great mighty god', 'great big town', 'great big city', 'field grain pellet', 'grain pellet jar', 'jar jars in rack', 'basket with handle', 'basket lord every', 'thing lord every', 'stone pillar grandfather', 'pillar grandfather old man', 'old man youth', 'youth become man', 'to become life', 'scarab become god', 'god become king', 'king seated god', 'seat throne god', 'throne king sedge', 'sedge king power', 'cobra horned viper', 'horned viper snake', 'snake rope coil of rope', 'tethering rope vessel', 'vessel water ripple', 'river water ripple', 'sky star swallow', 'swallow great star', 'storm sky fear', 'fire strength force', 'stability djed pillar', 'djed pillar stability', 'book writing scribe', 'reed leaf plant', 'plant life ankh', 'above horizon sky', 'star above mountain', 'mountain near desert', 'desert hill slope', 'road enters town', 'gate has door bolt', 'house has door bolt', 'house holds people', 'people follow road', 'people fear power', 'power of god', 'god great big', 'god gives strength', 'strong man backbone', 'hand holds rope', 'rope tethering rope', 'water ripple lake', 'lake near river', 'river near riverbank', 'plows tills field', 'field grows grain', 'jar holds grain', 'offering in vessel', 'god seated throne', 'throne power king', 'he king strong', 'king gives order', 'people obey authority', 'to give life', 'life ankh power', 'life fills heart', 'heart holds fear', 'fear of storm', 'storm in sky', 'fire gives fear', 'eye sees face / upon', 'face / on (upon) god', 'mouth eat / drink / speak', 'hear / listen god', 'god hears people', 'writing / scribe records', 'mother gives milk jar', 'father protects people', 'old man venerated / marrow', 'venerated / marrow strength', 'soul (ba) west', 'west underground soul', 'ka (spirit) life', 'ka (the spirit / the double) lives', 'scarab / become life', 'to return / retreat west', 'stability (djed) power', 'pillar / grandfather stability', 'stone pillar / grandfather', 'temple stone pillar', 'cobra guards throne', 'above mountain horizon', 'horizon above desert', 'desert near town', 'river near field', 'field near house', 'house near gate', 'gate near road', 'road near city / town', 'city / town people', 'people near temple', 'temple near river', 'temple near mountain', 'god near temple', 'god above people', 'god protects town', 'king protects town', 'authority gives order', 'power gives order', 'order gives peace', 'peace / satisfy heart', 'heart loves life', 'life gives joy', 'life fills ka (spirit)', 'ka (spirit) joins soul (ba)', 'soul (ba) seeks west', 'west beyond town', 'west beyond mountain', 'underground beyond west', 'underground holds soul (ba)', 'pillar / grandfather supports house', 'house built stone', 'stone cuts chisel', 'chisel cuts stone', 'plows (tills) field', 'field yields grain / pellet', 'grain / pellet fills jar', 'jar holds offering', 'offering placed temple', 'offering pleases god', 'god gives life (ankh)', 'life (ankh) gives power', 'strength / force king', 'hand holds sickle', 'sickle cuts grain / pellet', 'rope coils snake', 'cobra guards gate', 'gate guards town', 'owl hears night', 'eye sees sky', 'star above town', 'storm crosses sky', 'fire burns offering', 'feather (truth/maat) judges heart', 'heart obeys maat', 'stability (djed) endures', 'djed gives order', 'seat / throne king', 'seated woman listens', 'servant obeys master (lord) / all (every)', 'master (lord) / all (every) commands', 'lord / every thing', 'thing exists', 'opens / exists (or is found) temple', 'writing / scribe records life', 'papyrus scroll records', 'book preserves writing', 'senet board played', 'youth learns writing', 'old man teaches youth', 'sky above mountain', 'house face upon', 'hill behind desert', 'king become god', 'he king great', 'man eat / drink / speak', 'god hear / listen', 'star sky swallow', 'authority lord / every', 'lord / every people', 'master (lord) / all (every)', 'throne god deity', 'seated god / king', 'sedge (king) throne', 'snake coil of rope', 'field grain / pellet', 'grain / pellet jar', 'offering peace / altar', 'peace / altar temple', 'heart feather (truth/maat)', 'feather (truth/maat) maat', 'brick town house', 'writing / scribe man', 'book writing / scribe', 'woman mother father', 'father mother child', 'above desert hill', 'desert behind mountain', 'mountain above horizon', 'horizon face / upon', 'sky face / upon', 'star face / upon', 'town face / upon', 'gate face / upon', 'temple face / upon', 'god behind temple', 'temple behind town', 'town behind river', 'river behind lake', 'lake behind mountain', 'mountain behind sky', 'west behind desert', 'underground behind west', 'soul (ba) underground', 'ka (spirit) underground', 'ka (the spirit / the double) soul (ba)', 'life (ankh) ka (spirit)', 'life (ankh) soul (ba)', 'power great mighty', 'great / mighty king', 'he / king power', 'seat / throne deity', 'throne god / deity', 'sedge (king) power', 'authority power king', 'lord / every authority', 'servant power authority', 'people authority fear', 'fear power god', 'storm fear sky', 'fire power strength / force', 'strength / force strong', 'strong backbone power', 'side / rib backbone', 'forearm hand power', 'foot road desert', 'road desert town', 'grain / pellet offering', 'offering god / deity', 'peace / altar offering', 'peace / content (satisfied) heart', 'peace / satisfy god', 'heart peace / satisfy', 'feather (truth/maat) heart', 'maat stability (djed)', 'stability (djed) pillar / grandfather', 'pillar / grandfather temple', 'stone temple pillar / grandfather', 'brick house town', 'basket (lord / all) offering', 'basket with handle offering', 'milk jar vessel', 'vessel offering god', 'jars in rack house', 'papyrus clump plant', 'reed shelter house', 'lotus plant water ripple', 'owl night sky', 'eye sees horizon', 'hear / listen people', 'writing / scribe book', 'book papyrus scroll', 'thing power authority', 'venerated / marrow strength / force', 'youth strong power', 'woman seated woman', 'man seated man', 'god sees man', 'mother loves youth', 'king gives life', 'scribe makes book', 'servant plows field', 'man hears god', 'youth eats bread', 'heart loves beauty', 'city becomes great', 'man sees snake', 'god hears offering', 'woman makes fire', 'father sees youth', 'king gives bread', 'scribe hears authority', 'god becomes great', 'life becomes sweet', 'man plows field', 'king loves power', 'scribe sees book', 'god makes sky', 'woman hears god', 'youth sees star', 'servant makes fire', 'man eats grain', 'heart becomes peace', 'scribe writes truth', 'king sees city', 'man drinks water', 'mother hears youth', 'scribe sees scroll', 'people fear cobra', 'king makes offering', 'god loves truth', 'man eats loaf of bread', 'youth drinks milk jar', 'road behind house', 'scribe sees senet board', 'servant gives jar', 'mother gives birth youth', 'father speaks truth', 'heart hears authority', 'snake behind brick', 'lake behind temple', 'star above sky', 'woman sees lotus plant', 'man gives chisel', 'king makes temple', 'scribe becomes old man', 'god hears soul', 'life becomes great', 'people love peace', 'youth sees horizon', 'man plows riverbank', 'father makes basket with handle', 'woman becomes mother', 'god loves ka (spirit)', 'city behind mountain', 'scribe hears god', 'king sees papyrus scroll', 'youth loves sweet', 'fire above altar', 'man makes gate', 'people see throne', 'god gives stability (djed)', 'father hears servant', 'woman sees eye', 'king speaks authority', 'scribe makes writing', 'man sees desert hill', 'god emerges sky', 'youth eats grain', 'mother sees star', 'man hears owl', 'god makes horizon', 'man sees adze', 'scribe sees chisel', 'king sees club', 'youth sees senet board', 'servant sees sickle', 'woman sees vessel', 'father makes door bolt', 'mother makes basket with handle', 'god sees soul (ba)', 'man cuts plant', 'king loves authority', 'youth eats grain / pellet', 'servant sees riverbank', 'father sees mountain', 'man hears storm', 'mother sees eye', 'scribe sees quail chick', 'king loves throne', 'god hears heart', 'youth sees sky', 'man sees cobra', 'scribe makes papyrus scroll', 'servant gives offering', 'king hears truth', 'father loves king', 'woman hears people', 'god makes field', 'man sees desert hare (to be)', 'king gives ring', 'scribe sees lake', 'youth sees fire', 'servant plows road', 'god loves heart', 'mother eats loaf of bread', 'father sees god', 'man makes house', 'king sees people', 'scribe loves authority', 'youth sees swallow', 'servant gives vessel', 'man sees coil of rope', 'king makes city / town', 'scribe sees writing / scribe', 'god sees ka (spirit)', 'mother loves father', 'youth sees beauty / good', 'man sees head of ox', 'scribe sees papyrus clump', 'servant gives club', 'king sees backbone', 'man sees head of bird', 'youth fears storm', 'father makes jar', 'mother sees placenta', 'god loves peace / satisfy', 'city / town becomes great / big', 'life (ankh) upon road', 'scribe hears god / deity', 'servant sees reed shelter', 'king gives authority', 'god loves ka (the spirit / the double)', 'man sees horned viper', 'sky above hill', 'water ripple upon stone', 'father gives ring', 'scribe sees jars in rack', 'servant makes brick', 'god makes lotus plant', 'people see king', 'youth loves beauty / good', 'mother sees head of bird', 'heart becomes strong', 'woman makes offering', 'scribe sees stool / mat', 'father loves old man', 'life (ankh) becomes great / mighty', 'youth sees swallow (great)', 'god makes people', 'scribe sees single stroke', 'king gives basket (lord / all)', 'man sees hill slope', 'servant makes gate', 'woman hears cobra', 'scribe sees three fox skins', 'god gives strength / force', 'youth sees quail chick', 'mother sees lotus plant', 'servant plows side / rib', 'scribe sees placenta', 'man eats lotus plant', 'king gives adze', 'youth hears backbone', 'servant plows desert hill', 'mother sees horned viper', 'father makes conical loaf (give)', 'god loves old man', 'scribe hears river', 'king sees animal belly', 'youth loves feather (truth/maat)', 'man cuts basket with handle', 'servant gives head of bird', 'mother hears swallow (great)', 'father sees side / rib', 'god gives basket (lord / all)', 'scribe makes single stroke', 'king loves lake', 'youth sees hill slope', 'man drinks milk jar', 'servant fears storm', 'mother sees reed leaf', 'father gives jar', 'scribe hears people', 'king eats grain / pellet', 'youth loves ka (the spirit / the double)', 'man sees stool / mat', 'servant plows riverbank', 'mother makes fire', 'father hears cobra', 'god gives vessel', 'youth makes offering', 'servant hears master (lord) / all (every)', 'mother loves peace / altar', 'father sees star', 'god emerges hill', 'scribe writes thing', 'youth sees door bolt', 'man sees road', 'servant gives loaf of bread', 'mother sees woman', 'father hears god / deity', 'god makes mountain', 'scribe sees eye', 'king loves peace / satisfy', 'youth sees adze', 'scribe sees backbone', 'man sees basket (lord / all)', 'servant sees basket with handle', 'god becomes swallow', 'mother sees book', 'father makes brick', 'servant gives chisel', 'youth hears club', 'king sees cobra', 'scribe gives conical loaf (give)', 'god makes cross', 'youth cuts plant', 'mother sees desert', 'father sees desert hare (to be)', 'servant sees desert hill', 'king makes door bolt', 'man sees face / upon', 'god gives feather (truth/maat)', 'mother sees field', 'father sees fire', 'servant sees folded cloth', 'scribe sees foot', 'king sees forearm', 'youth sees gate', 'god gives birth / begets', 'man hears god / deity', 'mother sees grain / pellet', 'father sees hand', 'servant sees head of bird', 'scribe sees head of ox', 'king hears heart', 'youth sees hill', 'god makes hill slope', 'man sees hoe', 'mother sees horizon', 'father sees horned viper', 'servant makes house', 'scribe sees jar', 'king sees jars in rack', 'youth sees lake', 'god gives thousand', 'man loves lotus plant', 'mother sees milk jar', 'father makes offering', 'servant sees old man', 'scribe sees papyrus scroll', 'youth becomes god', 'man sees underground', 'king hears storm', 'servant gives ring', 'woman eats conical loaf (give)', 'god loves soul (ba)', 'father sees pillar / grandfather', 'scribe hears swallow', 'king gives thousand', 'youth loves life (ankh)', 'mother loves peace / content (satisfied)', 'king sees town', 'god makes desert hill', 'woman sees star', 'father makes basket (lord / all)', 'mother sees jars in rack', 'servant sees master (lord) / all (every)', 'youth hears authority', 'god gives peace / satisfy', 'man drinks jar', 'king gives basket with handle', 'mother loves beauty / good', 'king sees city / town', 'god gives adze', 'father sees west', 'mother loves scribe', 'man makes vessel', 'old man eats grain / pellet', 'owl sees desert', 'quail chick fears cobra', 'seated man sees throne', 'sedge (king) loves life (ankh)', 'woman makes milk jar', 'father sees head of ox', 'mother sees animal belly', 'scribe hears water ripple', 'king gives stability (djed)', 'servant sees side / rib', 'youth sees placenta', 'man hears backbone', 'old man makes brick', 'king gives conical loaf (give)', 'father cuts papyrus clump', 'servant fears horned viper', 'god makes road', 'man drinks water ripple', 'scribe sees folded cloth', 'king hears authority', 'woman sees reed shelter', 'father makes tethering rope', 'mother hears soul (ba)', 'servant plows hill slope', 'youth sees face / upon', 'old man sees west', 'scribe writes writing / scribe', 'man sees twisted flax', 'father loves ka (spirit)', 'mother sees forearm', 'god loves beautiful / good', 'youth sees head of bird', 'scribe hears master (lord) / all (every)', 'king sees riverbank', 'woman hears storm', 'father makes coil of rope', 'mother sees hand', 'servant sees gate', 'god gives great / mighty', 'man sees chisel', 'owl sees hill', 'woman sees reed leaf', 'scribe hears stool / mat', 'king makes lake', 'youth sees underground', 'servant sees pool', 'father eats grain / pellet', 'scribe writes authority', 'man sees animal belly', 'people love peace / satisfy', 'king speaks beauty / good', 'servant gives adze', 'youth drinks water ripple', 'woman sees owl', 'father sees hill slope', 'mother hears storm', 'youth loves old man', 'old man hears youth', 'people fear fire', 'scribe sees head of bird', 'god gives conical loaf (give)', 'youth eats loaf of bread', 'old man sees god / deity', 'king sees mountain', 'servant gives milk jar', 'mother sees scribe', 'youth sees pool', 'king gives tethering rope', 'servant sees twisted flax', 'god loves peace / content (satisfied)', 'man sees owl', 'mother hears heart', 'father makes sickle', 'scribe sees scribe / writing', 'youth sees head of ox', 'king sees placenta', 'god gives basket with handle', 'servant sees hill slope', 'old man sees star', 'woman loves beauty / good', 'man sees side / rib', 'king makes gate', 'people see god / deity', 'mother loves child (youth)', 'king hears scribe', 'god makes fire', 'servant sees adze', 'youth loves peace / satisfy', 'man sees backbone', 'scribe sees reed leaf', 'servant sees senet board', 'mother sees house', 'scribe sees lotus plant', 'youth sees jar']

# %%
# Shuffled Sentences (Test Input)
shuffled_sentences_raw = [
"""god
great
king""",
"""gives
king
he""",
"""gives
life
god""",
"""gives
life
father""",
"""gives
mother
birth""",
"""god
gives
power""",
"""god
power
great""",
"""city
town
beautiful""",
"""satisfy
heart
peace""",
"""love
heart
life""",
"""man
love
woman""",
"""life
gives
woman""",
"""god
hears
prayer""",
"""sees
people
god""",
"""people
fear
god""",
"""strong
power
king""",
"""rules
town
king""",
"""thing
lord
every""",
"""people
lord
master""",
"""master
hears
servant""",
"""old
wisdom
man""",
"""force
strength
youth""",
"""sees
eye
star""",
"""sky
star
in""",
"""sun
above
horizon""",
"""water
ripple
river""",
"""flows
river
town""",
"""field
riverbank
grain""",
"""gives
grain
field""",
"""life
grain
gives""",
"""eats
bread
man""",
"""loaf
bread
of""",
"""offering
peace
gives""",
"""peace
gives
temple""",
"""temple
god
in""",
"""house
behind
gate""",
"""opens
gate
town""",
"""leads
road
town""",
"""above
mountain
town""",
"""desert
slope
hill""",
"""desert
lives
hare""",
"""hill
desert
west""",
"""west
underground
dead""",
"""ba
lives
soul""",
"""lives
spirit
ka""",
"""life
gives
ankh""",
"""gives
ankh
god""",
"""scarab
become
life""",
"""god
become
to""",
"""king
god
becomes""",
"""king
of
throne""",
"""throne
king
seat""",
"""seated
god
throne""",
"""seated
man
speaks""",
"""mouth
speaks
truth""",
"""maat
feather
truth""",
"""truth
weighs
heart""",
"""of
heart
judgment""",
"""of
god
eye""",
"""guards
cobra
king""",
"""snake
guards
temple""",
"""gives
fire
power""",
"""storm
fear
gives""",
"""people
fear
storm""",
"""stone
builds
temple""",
"""builds
brick
house""",
"""supports
pillar
temple""",
"""stability
djed
power""",
"""strong
backbone
king""",
"""offering
gives
hand""",
"""road
foot
walks""",
"""door
man
opens""",
"""door
bolt
opens""",
"""holds
jar
water""",
"""holds
lake
water""",
"""river
gives
water""",
"""gives
water
life""",
"""life
gives
plant""",
"""plant
life
lotus""",
"""papyrus
scroll
writing""",
"""man
writing
scribe""",
"""book
writes
scribe""",
"""wisdom
book
holds""",
"""listen
god
hear""",
"""hears
god
voice""",
"""drink
eats
mouth""",
"""bread
offering
sweet""",
"""satisfied
content
peace""",
"""gives
god
peace""",
"""altar
peace
gives""",
"""protects
people
god""",
"""king
protects
people""",
"""power
king
of""",
"""strength
god
of""",
"""mighty
king
great""",
"""god
mighty
great""",
"""town
lord
of""",
"""town
city
people""",
"""love
people
king""",
"""serve
king
people""",
"""serves
servant
lord""",
"""loves
child
father""",
"""child
loves
mother""",
"""becomes
youth
child""",
"""youth
man
becomes""",
"""emerges
horizon
god""",
"""sun
rises
sky""",
"""star
holds
sky""",
"""road
star
guides""",
"""crosses
desert
road""",
"""desert
surrounds
town""",
"""town
gate
has""",
"""gate
city
protects""",
"""holds
city
people""",
"""build
people
house""",
"""door
has
house""",
"""door
opens
house""",
"""enters
house
man""",
"""sits
stool
woman""",
"""seated
woman
speaks""",
"""words
speaks
mouth""",
"""power
give
words""",
"""king
power
strengthens""",
"""throne
sits
king""",
"""in
throne
temple""",
"""holds
god
temple""",
"""dwells
temple
god""",
"""altar
placed
offering""",
"""altar
temple
in""",
"""offering
brings
servant""",
"""holds
jar
hand""",
"""milk
jar
holds""",
"""milk
offering
jar""",
"""mother
child
feeds""",
"""child
milk
drinks""",
"""protects
family
father""",
"""house
family
lives""",
"""flows
river
life""",
"""river
feeds
field""",
"""grows
plant
field""",
"""plant
feeds
people""",
"""plow
people
field""",
"""tills
field
hoe""",
"""cuts
grain
sickle""",
"""stored
grain
jars""",
"""in
jars
rack""",
"""house
rack
in""",
"""builds
stone
wall""",
"""guards
wall
town""",
"""near
town
river""",
"""river
lake
near""",
"""sky
lake
reflects""",
"""sky
above
earth""",
"""sky
touches
mountain""",
"""mountain
hill
near""",
"""hill
slope
path""",
"""path
temple
leads""",
"""enter
temple
pilgrims""",
"""pilgrims
god
hears""",
"""brings
peace
prayer""",
"""peace
calms
heart""",
"""truth
seeks
heart""",
"""weighs
heart
truth""",
"""feather
truth
measures""",
"""order
brings
maat""",
"""order
brings
stability""",
"""gives
djed
stability""",
"""stability
gives
power""",
"""maintains
power
order""",
"""order
maintains
king""",
"""comes
authority
law""",
"""of
authority
king""",
"""king
crown
wears""",
"""king
sedge
symbol""",
"""cobra
crowns
king""",
"""guards
viper
horned""",
"""snake
coils
rope""",
"""vessel
rope
binds""",
"""water
floats
vessel""",
"""moves
water
ripple""",
"""river
crosses
boat""",
"""place
marks
cross""",
"""memory
holds
place""",
"""memory
lives
soul""",
"""soul
ba
flies""",
"""head
watches
bird""",
"""watches
eye
horizon""",
"""meets
horizon
sky""",
"""dead
west
holds""",
"""soul
underground
holds""",
"""life
returns
soul""",
"""life
scarab
renews""",
"""west
to
return""",
"""man
old
remembers""",
"""seeks
youth
strength""",
"""strength
future
builds""",
"""opens
god
horizon""",
"""above
land
horizon""",
"""field
holds
land""",
"""beside
river
field""",
"""river
beside
town""",
"""gate
town
beyond""",
"""house
gate
behind""",
"""contains
house
family""",
"""peace
family
loves""",
"""heart
peace
fills""",
"""ka
holds
heart""",
"""ka
soul
joins""",
"""seeks
west
soul""",
"""beyond
horizon
west""",
"""underground
ancestors
holds""",
"""ancestor
pillar
grandfather""",
"""ancestor
wisdom
gives""",
"""wisdom
guides
youth""",
"""youth
gains
strength""",
"""supports
backbone
strength""",
"""man
backbone
supports""",
"""man
walks
road""",
"""between
towns
road""",
"""town
meets
city""",
"""city
temple
has""",
"""sky
temple
faces""",
"""temple
sky
above""",
"""temple
star
above""",
"""god
beneath
sky""",
"""rules
cosmos
god""",
"""power
god
flows""",
"""world
shapes
power""",
"""world
holds
people""",
"""honor
people
god""",
"""people
bring
offering""",
"""offering
on
altar""",
"""altar
before
god""",
"""god
offering
accepts""",
"""hand
lifts
loaf""",
"""feeds
loaf
people""",
"""drink
eat
people""",
"""mouth
tastes
sweet""",
"""pleases
sweet
heart""",
"""heart
seeks
peace""",
"""god
peace
satisfies""",
"""god
favor
grants""",
"""life
brings
favor""",
"""life
fills
land""",
"""land
grain
grows""",
"""jar
grain
fills""",
"""jar
seals
food""",
"""feeds
food
family""",
"""honors
family
ancestors""",
"""ancestors
house
guard""",
"""near
road
house""",
"""road
near
riverbank""",
"""slopes
hill
riverbank""",
"""near
desert
hill""",
"""beyond
hill
desert""",
"""silence
desert
holds""",
"""silence
fear
brings""",
"""respects
fear
god""",
"""god
commands
authority""",
"""authority
king
guides""",
"""sits
seat
king""",
"""inside
seat
throne""",
"""palace
inside
throne""",
"""near
temple
palace""",
"""temple
holds
writing""",
"""knows
writing
scribe""",
"""life
records
writing""",
"""book
recorded
life""",
"""book
kept
temple""",
"""temple
truth
preserves""",
"""heart
judged
maat""",
"""order
ensures
maat""",
"""order
world
sustains""",
"""time
endures
world""",
"""time
brings
change""",
"""brings
change
becoming""",
"""becoming
life
creates""",
"""people
renews
life""",
"""horizon
above
god""",
"""horizon
mountain
above""",
"""behind
mountain
town""",
"""behind
gate
town""",
"""house
opens
gate""",
"""contains
house
people""",
"""fear
people
authority""",
"""rules
king
he""",
"""king
mighty
great""",
"""great
king
power""",
"""strength
power
gives""",
"""man
backbone
strong""",
"""heart
man
has""",
"""heart
loves
truth""",
"""stability
maat
gives""",
"""power
people
protects""",
"""offering
god
before""",
"""faces
temple
horizon""",
"""town
brick
builds""",
"""road
river
beside""",
"""riverbank
river
beside""",
"""riverbank
field
near""",
"""life
ankh
god""",
"""gives
ankh
life""",
"""people
life
fills""",
"""love
people
life""",
"""heart
peace
satisfies""",
"""temple
altar
peace""",
"""mother
loves
father""",
"""birth
youth
gives""",
"""old
wise
man""",
"""old
wisdom
heart""",
"""storm
fear
brings""",
"""fear
god
of""",
"""cobra
temple
guards""",
"""water
vessel
holds""",
"""west
soul
ba""",
"""seat
throne
king""",
"""records
writing
scribe""",
"""holds
book
writing""",
"""judges
truth
heart""",
"""belly
eats
animal""",
"""eats
drink
man""",
"""eats
mouth
grain""",
"""feeds
people
grain""",
"""town
people
live""",
"""town
city
house""",
"""gate
wall
behind""",
"""town
road
behind""",
"""behind
mountain
hill""",
"""road
slope
hill""",
"""holds
underground
west""",
"""soul
life
ba""",
"""life
ka
spirit""",
"""gives
power
life""",
"""strong
makes
strength""",
"""king
strong
rules""",
"""king
he
authority""",
"""authority
power
gives""",
"""lord
every
people""",
"""servant
lord
master""",
"""work
does
servant""",
"""work
to
do""",
"""hand
work
does""",
"""road
crosses
river""",
"""meets
river
lake""",
"""ripple
lake
water""",
"""plant
grows
field""",
"""field
plows
tills""",
"""hoe
field
plows""",
"""sickle
cuts
plant""",
"""grain
plant
gives""",
"""vessel
fills
grain""",
"""offering
vessel
holds""",
"""god
mighty
great""",
"""power
great
mighty""",
"""people
god
hear""",
"""voice
listen
hear""",
"""face
sees
eye""",
"""face
god
upon""",
"""heart
fear
feels""",
"""respects
fear
authority""",
"""gives
stone
strength""",
"""gives
stability
pillar""",
"""backbone
gives
strength""",
"""life
hand
gives""",
"""to
become
strong""",
"""man
becomes
father""",
"""becomes
old
father
man""",
"""venerated
old
man""",
"""strength
venerated
marrow""",
"""writing
book
scribe""",
"""papyrus
book
scroll""",
"""senet
game
board""",
"""people
play
board
senet""",
"""temple
god
house""",
"""god
throne
seat""",
"""man
listens
seated""",
"""night
owl
sees""",
"""lights
star
sky""",
"""above
town
sky""",
"""horizon
above
sky""",
"""god
upon
face""",
"""upon
temple
face""",
"""upon
temple
face""",
"""upon
eye
face""",
"""upon
man
face""",
"""face
woman
upon""",
"""upon
king
face""",
"""gate
behind
god""",
"""behind
house
town""",
"""town
behind
city""",
"""behind
river
city""",
"""river
behind
riverbank""",
"""riverbank
field
behind""",
"""field
hill
behind""",
"""behind
mountain
hill""",
"""town
river
above""",
"""above
lake
river""",
"""lake
underground
above""",
"""west
soul
underground""",
"""soul
ba
west""",
"""soul
ba
god""",
"""spirit
god
ka""",
"""spirit
ka
god""",
"""ankh
life
ka""",
"""ankh
life
god""",
"""power
force
strength""",
"""strength
king
force""",
"""backbone
king
strong""",
"""side
backbone
rib""",
"""rib
man
side""",
"""man
hand
forearm""",
"""road
town
foot""",
"""town
city
road""",
"""people
man
city""",
"""people
man
seated""",
"""drink
mouth
eat
speak""",
"""people
listen
hear""",
"""people
hear
king""",
"""king
hears
people""",
"""sees
god
eye""",
"""heart
god
sees""",
"""god
heart
fear""",
"""god
fear
authority""",
"""lord
authority
every""",
"""all
master
lord""",
"""seated
man
servant""",
"""work
do
servant""",
"""to
do
make""",
"""offering
to
give""",
"""offering
altar
peace""",
"""altar
temple
god""",
"""temple
deity
god""",
"""great
god
deity""",
"""mighty
great
god""",
"""great
town
big""",
"""great
big
city""",
"""grain
pellet
field""",
"""pellet
jar
grain""",
"""jars
jar
rack
in""",
"""handle
with
basket""",
"""basket
lord
every""",
"""every
thing
lord""",
"""stone
pillar
grandfather""",
"""old
grandfather
pillar
man""",
"""old
youth
man""",
"""youth
man
become""",
"""become
to
life""",
"""god
become
scarab""",
"""god
king
become""",
"""king
god
seated""",
"""throne
seat
god""",
"""sedge
throne
king""",
"""sedge
power
king""",
"""viper
cobra
horned""",
"""snake
horned
viper""",
"""coil
snake
rope
of
rope""",
"""vessel
rope
tethering""",
"""vessel
water
ripple""",
"""river
water
ripple""",
"""star
swallow
sky""",
"""star
swallow
great""",
"""storm
fear
sky""",
"""fire
strength
force""",
"""djed
pillar
stability""",
"""pillar
djed
stability""",
"""writing
book
scribe""",
"""plant
reed
leaf""",
"""plant
life
ankh""",
"""horizon
sky
above""",
"""mountain
above
star""",
"""near
desert
mountain""",
"""desert
slope
hill""",
"""road
enters
town""",
"""gate
door
has
bolt""",
"""door
house
bolt
has""",
"""people
house
holds""",
"""follow
people
road""",
"""power
fear
people""",
"""power
god
of""",
"""god
great
big""",
"""strength
gives
god""",
"""strong
man
backbone""",
"""hand
holds
rope""",
"""rope
tethering
rope""",
"""water
ripple
lake""",
"""lake
river
near""",
"""river
near
riverbank""",
"""plows
field
tills""",
"""grows
grain
field""",
"""jar
holds
grain""",
"""vessel
in
offering""",
"""throne
seated
god""",
"""throne
power
king""",
"""he
king
strong""",
"""order
king
gives""",
"""authority
people
obey""",
"""life
give
to""",
"""power
ankh
life""",
"""heart
fills
life""",
"""holds
fear
heart""",
"""storm
fear
of""",
"""sky
in
storm""",
"""fire
fear
gives""",
"""sees
eye
face
/
upon""",
"""face
god
/
(upon)
on""",
"""/
eat
drink
speak
mouth
/""",
"""god
hear
listen
/""",
"""people
god
hears""",
"""scribe
records
/
writing""",
"""gives
jar
mother
milk""",
"""people
father
protects""",
"""old
/
man
marrow
venerated""",
"""marrow
strength
venerated
/""",
"""(ba)
soul
west""",
"""underground
soul
west""",
"""life
(spirit)
ka""",
"""lives
ka
spirit
/
(the
double)
the""",
"""scarab
become
life
/""",
"""return
to
west
/
retreat""",
"""stability
power
(djed)""",
"""grandfather
stability
pillar
/""",
"""stone
pillar
grandfather
/""",
"""temple
stone
pillar""",
"""cobra
guards
throne""",
"""above
horizon
mountain""",
"""desert
above
horizon""",
"""town
desert
near""",
"""field
near
river""",
"""field
near
house""",
"""house
near
gate""",
"""gate
near
road""",
"""city
town
near
/
road""",
"""people
/
town
city""",
"""temple
people
near""",
"""temple
near
river""",
"""near
mountain
temple""",
"""god
near
temple""",
"""above
god
people""",
"""protects
god
town""",
"""protects
king
town""",
"""authority
order
gives""",
"""order
gives
power""",
"""gives
order
peace""",
"""heart
satisfy
/
peace""",
"""heart
loves
life""",
"""gives
joy
life""",
"""life
(spirit)
ka
fills""",
"""soul
(spirit)
ka
joins
(ba)""",
"""soul
seeks
(ba)
west""",
"""town
beyond
west""",
"""beyond
mountain
west""",
"""west
beyond
underground""",
"""(ba)
holds
underground
soul""",
"""/
house
supports
grandfather
pillar""",
"""house
stone
built""",
"""stone
cuts
chisel""",
"""chisel
cuts
stone""",
"""plows
(tills)
field""",
"""grain
pellet
/
yields
field""",
"""/
grain
fills
pellet
jar""",
"""holds
jar
offering""",
"""offering
placed
temple""",
"""offering
pleases
god""",
"""gives
life
god
(ankh)""",
"""gives
(ankh)
power
life""",
"""/
force
strength
king""",
"""holds
sickle
hand""",
"""sickle
grain
cuts
pellet
/""",
"""coils
rope
snake""",
"""gate
cobra
guards""",
"""gate
town
guards""",
"""night
owl
hears""",
"""eye
sees
sky""",
"""town
above
star""",
"""sky
storm
crosses""",
"""offering
fire
burns""",
"""feather
(truth/maat)
heart
judges""",
"""maat
obeys
heart""",
"""endures
stability
(djed)""",
"""order
gives
djed""",
"""/
king
throne
seat""",
"""woman
seated
listens""",
"""(lord)
(every)
all
/
obeys
master
servant""",
"""all
commands
/
(lord)
(every)
master""",
"""every
lord
thing
/""",
"""exists
thing""",
"""is
(or
opens
temple
found)
/
exists""",
"""scribe
records
life
/
writing""",
"""records
scroll
papyrus""",
"""preserves
writing
book""",
"""played
senet
board""",
"""writing
learns
youth""",
"""man
youth
teaches
old""",
"""sky
mountain
above""",
"""upon
house
face""",
"""desert
hill
behind""",
"""become
king
god""",
"""he
king
great""",
"""speak
/
eat
/
man
drink""",
"""hear
god
/
listen""",
"""star
swallow
sky""",
"""/
lord
every
authority""",
"""people
every
lord
/""",
"""master
all
(lord)
(every)
/""",
"""throne
deity
god""",
"""god
king
/
seated""",
"""(king)
sedge
throne""",
"""of
snake
coil
rope""",
"""field
/
grain
pellet""",
"""pellet
grain
/
jar""",
"""offering
altar
peace
/""",
"""temple
peace
/
altar""",
"""heart
feather
(truth/maat)""",
"""(truth/maat)
maat
feather""",
"""town
house
brick""",
"""scribe
/
writing
man""",
"""scribe
book
/
writing""",
"""woman
mother
father""",
"""mother
father
child""",
"""above
hill
desert""",
"""desert
behind
mountain""",
"""above
mountain
horizon""",
"""horizon
face
upon
/""",
"""face
upon
sky
/""",
"""star
upon
/
face""",
"""/
upon
town
face""",
"""upon
face
gate
/""",
"""/
temple
upon
face""",
"""god
behind
temple""",
"""behind
town
temple""",
"""town
river
behind""",
"""river
lake
behind""",
"""behind
mountain
lake""",
"""sky
behind
mountain""",
"""behind
desert
west""",
"""behind
underground
west""",
"""(ba)
underground
soul""",
"""ka
underground
(spirit)""",
"""ka
double)
/
the
soul
(the
spirit
(ba)""",
"""(ankh)
ka
(spirit)
life""",
"""(ba)
life
soul
(ankh)""",
"""great
power
mighty""",
"""great
king
/
mighty""",
"""he
/
king
power""",
"""throne
seat
/
deity""",
"""deity
/
god
throne""",
"""power
(king)
sedge""",
"""authority
power
king""",
"""/
authority
lord
every""",
"""authority
servant
power""",
"""authority
fear
people""",
"""god
fear
power""",
"""sky
fear
storm""",
"""power
/
fire
force
strength""",
"""strength
/
force
strong""",
"""backbone
power
strong""",
"""/
side
rib
backbone""",
"""forearm
hand
power""",
"""desert
road
foot""",
"""desert
road
town""",
"""pellet
/
grain
offering""",
"""deity
/
god
offering""",
"""peace
/
altar
offering""",
"""heart
(satisfied)
/
peace
content""",
"""god
/
peace
satisfy""",
"""satisfy
peace
heart
/""",
"""(truth/maat)
heart
feather""",
"""maat
(djed)
stability""",
"""/
pillar
(djed)
stability
grandfather""",
"""temple
/
pillar
grandfather""",
"""grandfather
/
pillar
stone
temple""",
"""house
brick
town""",
"""(lord
basket
all)
offering
/""",
"""offering
handle
basket
with""",
"""vessel
milk
jar""",
"""offering
god
vessel""",
"""rack
in
house
jars""",
"""papyrus
plant
clump""",
"""reed
shelter
house""",
"""ripple
plant
lotus
water""",
"""sky
night
owl""",
"""eye
horizon
sees""",
"""/
hear
people
listen""",
"""/
writing
book
scribe""",
"""book
scroll
papyrus""",
"""authority
thing
power""",
"""/
strength
force
/
marrow
venerated""",
"""youth
strong
power""",
"""woman
woman
seated""",
"""man
man
seated""",
"""god
man
sees""",
"""loves
mother
youth""",
"""life
gives
king""",
"""book
makes
scribe""",
"""plows
servant
field""",
"""hears
man
god""",
"""eats
bread
youth""",
"""heart
loves
beauty""",
"""great
city
becomes""",
"""man
snake
sees""",
"""god
offering
hears""",
"""woman
fire
makes""",
"""sees
father
youth""",
"""king
gives
bread""",
"""authority
hears
scribe""",
"""great
becomes
god""",
"""life
sweet
becomes""",
"""plows
man
field""",
"""power
king
loves""",
"""sees
scribe
book""",
"""god
sky
makes""",
"""woman
hears
god""",
"""sees
star
youth""",
"""servant
fire
makes""",
"""man
eats
grain""",
"""becomes
peace
heart""",
"""scribe
writes
truth""",
"""king
sees
city""",
"""water
drinks
man""",
"""youth
mother
hears""",
"""scroll
sees
scribe""",
"""cobra
people
fear""",
"""makes
offering
king""",
"""loves
truth
god""",
"""eats
of
bread
man
loaf""",
"""drinks
youth
jar
milk""",
"""road
behind
house""",
"""board
senet
scribe
sees""",
"""gives
servant
jar""",
"""birth
gives
mother
youth""",
"""truth
father
speaks""",
"""heart
authority
hears""",
"""snake
behind
brick""",
"""behind
temple
lake""",
"""star
sky
above""",
"""woman
lotus
plant
sees""",
"""man
chisel
gives""",
"""king
temple
makes""",
"""man
old
scribe
becomes""",
"""soul
god
hears""",
"""life
becomes
great""",
"""peace
people
love""",
"""sees
youth
horizon""",
"""riverbank
man
plows""",
"""with
father
handle
basket
makes""",
"""mother
woman
becomes""",
"""god
ka
(spirit)
loves""",
"""mountain
behind
city""",
"""god
hears
scribe""",
"""scroll
sees
king
papyrus""",
"""sweet
loves
youth""",
"""above
altar
fire""",
"""gate
man
makes""",
"""people
see
throne""",
"""(djed)
stability
god
gives""",
"""father
servant
hears""",
"""sees
woman
eye""",
"""king
speaks
authority""",
"""writing
scribe
makes""",
"""desert
sees
hill
man""",
"""emerges
sky
god""",
"""youth
eats
grain""",
"""star
sees
mother""",
"""owl
hears
man""",
"""makes
horizon
god""",
"""adze
sees
man""",
"""scribe
sees
chisel""",
"""sees
club
king""",
"""sees
youth
senet
board""",
"""sees
servant
sickle""",
"""sees
woman
vessel""",
"""bolt
father
makes
door""",
"""with
makes
mother
basket
handle""",
"""(ba)
god
soul
sees""",
"""man
cuts
plant""",
"""loves
authority
king""",
"""grain
eats
youth
pellet
/""",
"""servant
riverbank
sees""",
"""sees
father
mountain""",
"""storm
man
hears""",
"""eye
mother
sees""",
"""chick
sees
quail
scribe""",
"""loves
throne
king""",
"""god
heart
hears""",
"""sees
youth
sky""",
"""man
sees
cobra""",
"""makes
scribe
papyrus
scroll""",
"""gives
offering
servant""",
"""king
hears
truth""",
"""king
loves
father""",
"""hears
people
woman""",
"""makes
field
god""",
"""man
sees
(to
hare
be)
desert""",
"""ring
king
gives""",
"""sees
scribe
lake""",
"""youth
fire
sees""",
"""road
plows
servant""",
"""heart
god
loves""",
"""mother
bread
eats
of
loaf""",
"""father
god
sees""",
"""house
makes
man""",
"""king
sees
people""",
"""scribe
authority
loves""",
"""swallow
sees
youth""",
"""vessel
gives
servant""",
"""man
of
coil
sees
rope""",
"""town
makes
/
king
city""",
"""scribe
/
sees
scribe
writing""",
"""god
(spirit)
ka
sees""",
"""mother
father
loves""",
"""good
sees
/
beauty
youth""",
"""ox
sees
of
man
head""",
"""sees
scribe
clump
papyrus""",
"""gives
club
servant""",
"""king
sees
backbone""",
"""of
head
bird
sees
man""",
"""youth
fears
storm""",
"""father
jar
makes""",
"""sees
mother
placenta""",
"""god
/
peace
loves
satisfy""",
"""/
great
/
city
becomes
big
town""",
"""life
road
(ankh)
upon""",
"""/
deity
scribe
hears
god""",
"""servant
reed
shelter
sees""",
"""gives
king
authority""",
"""god
double)
/
loves
(the
ka
the
spirit""",
"""sees
horned
man
viper""",
"""above
hill
sky""",
"""upon
ripple
water
stone""",
"""ring
gives
father""",
"""in
sees
rack
scribe
jars""",
"""brick
servant
makes""",
"""lotus
god
plant
makes""",
"""see
king
people""",
"""beauty
youth
/
good
loves""",
"""of
mother
sees
bird
head""",
"""becomes
heart
strong""",
"""offering
makes
woman""",
"""scribe
sees
stool
mat
/""",
"""loves
father
old
man""",
"""great
/
mighty
life
becomes
(ankh)""",
"""sees
(great)
youth
swallow""",
"""people
makes
god""",
"""sees
single
stroke
scribe""",
"""all)
king
(lord
/
gives
basket""",
"""man
sees
slope
hill""",
"""gate
makes
servant""",
"""cobra
hears
woman""",
"""skins
scribe
fox
three
sees""",
"""/
god
strength
gives
force""",
"""youth
chick
quail
sees""",
"""sees
lotus
plant
mother""",
"""plows
rib
/
side
servant""",
"""scribe
sees
placenta""",
"""plant
lotus
eats
man""",
"""king
gives
adze""",
"""backbone
youth
hears""",
"""servant
desert
plows
hill""",
"""sees
viper
horned
mother""",
"""father
conical
(give)
loaf
makes""",
"""old
loves
god
man""",
"""hears
scribe
river""",
"""king
sees
belly
animal""",
"""(truth/maat)
youth
loves
feather""",
"""handle
with
cuts
man
basket""",
"""bird
head
gives
servant
of""",
"""(great)
swallow
mother
hears""",
"""rib
/
sees
side
father""",
"""god
/
(lord
basket
all)
gives""",
"""single
stroke
scribe
makes""",
"""king
loves
lake""",
"""youth
hill
sees
slope""",
"""milk
drinks
jar
man""",
"""servant
fears
storm""",
"""reed
leaf
mother
sees""",
"""gives
jar
father""",
"""scribe
people
hears""",
"""grain
king
eats
/
pellet""",
"""youth
the
/
spirit
ka
double)
(the
loves""",
"""sees
stool
mat
/
man""",
"""servant
riverbank
plows""",
"""fire
makes
mother""",
"""father
hears
cobra""",
"""god
gives
vessel""",
"""makes
youth
offering""",
"""all
/
(every)
master
(lord)
servant
hears""",
"""mother
/
peace
altar
loves""",
"""sees
father
star""",
"""emerges
hill
god""",
"""thing
writes
scribe""",
"""youth
sees
door
bolt""",
"""sees
road
man""",
"""of
gives
servant
bread
loaf""",
"""mother
sees
woman""",
"""father
hears
/
god
deity""",
"""god
makes
mountain""",
"""eye
scribe
sees""",
"""loves
king
/
satisfy
peace""",
"""youth
adze
sees""",
"""sees
scribe
backbone""",
"""sees
man
all)
basket
(lord
/""",
"""basket
sees
handle
with
servant""",
"""becomes
swallow
god""",
"""sees
book
mother""",
"""makes
brick
father""",
"""servant
chisel
gives""",
"""club
youth
hears""",
"""cobra
king
sees""",
"""gives
scribe
conical
(give)
loaf""",
"""makes
god
cross""",
"""cuts
youth
plant""",
"""mother
sees
desert""",
"""desert
father
sees
(to
hare
be)""",
"""servant
sees
desert
hill""",
"""king
makes
bolt
door""",
"""sees
face
man
/
upon""",
"""god
gives
(truth/maat)
feather""",
"""field
sees
mother""",
"""fire
father
sees""",
"""servant
folded
sees
cloth""",
"""scribe
foot
sees""",
"""forearm
king
sees""",
"""youth
sees
gate""",
"""begets
gives
god
birth
/""",
"""hears
deity
/
god
man""",
"""mother
sees
pellet
/
grain""",
"""father
sees
hand""",
"""servant
of
head
bird
sees""",
"""sees
of
scribe
head
ox""",
"""hears
king
heart""",
"""sees
hill
youth""",
"""slope
god
hill
makes""",
"""sees
hoe
man""",
"""mother
horizon
sees""",
"""sees
horned
father
viper""",
"""makes
house
servant""",
"""scribe
jar
sees""",
"""king
jars
rack
sees
in""",
"""lake
youth
sees""",
"""gives
thousand
god""",
"""lotus
loves
plant
man""",
"""milk
jar
mother
sees""",
"""offering
father
makes""",
"""sees
man
servant
old""",
"""sees
scribe
scroll
papyrus""",
"""youth
god
becomes""",
"""man
underground
sees""",
"""storm
hears
king""",
"""ring
servant
gives""",
"""loaf
eats
(give)
conical
woman""",
"""loves
god
(ba)
soul""",
"""/
grandfather
sees
pillar
father""",
"""swallow
hears
scribe""",
"""king
thousand
gives""",
"""life
(ankh)
loves
youth""",
"""peace
mother
content
/
(satisfied)
loves""",
"""town
sees
king""",
"""desert
makes
god
hill""",
"""woman
star
sees""",
"""(lord
all)
makes
father
/
basket""",
"""rack
in
jars
mother
sees""",
"""servant
/
all
(every)
sees
master
(lord)""",
"""hears
youth
authority""",
"""gives
god
/
satisfy
peace""",
"""drinks
jar
man""",
"""king
basket
handle
gives
with""",
"""loves
mother
beauty
good
/""",
"""/
town
city
king
sees""",
"""god
gives
adze""",
"""sees
west
father""",
"""loves
scribe
mother""",
"""makes
man
vessel""",
"""pellet
/
old
grain
eats
man""",
"""owl
sees
desert""",
"""cobra
chick
fears
quail""",
"""sees
throne
man
seated""",
"""loves
sedge
(king)
life
(ankh)""",
"""woman
makes
milk
jar""",
"""head
ox
sees
of
father""",
"""belly
mother
animal
sees""",
"""ripple
water
hears
scribe""",
"""gives
(djed)
stability
king""",
"""side
sees
rib
/
servant""",
"""placenta
youth
sees""",
"""backbone
hears
man""",
"""old
brick
man
makes""",
"""gives
conical
king
(give)
loaf""",
"""cuts
clump
father
papyrus""",
"""fears
servant
horned
viper""",
"""makes
god
road""",
"""water
drinks
ripple
man""",
"""scribe
sees
folded
cloth""",
"""king
hears
authority""",
"""reed
shelter
woman
sees""",
"""rope
makes
father
tethering""",
"""(ba)
mother
soul
hears""",
"""slope
plows
hill
servant""",
"""sees
face
/
youth
upon""",
"""man
sees
west
old""",
"""writes
writing
scribe
scribe
/""",
"""twisted
man
sees
flax""",
"""(spirit)
ka
father
loves""",
"""mother
sees
forearm""",
"""god
good
/
beautiful
loves""",
"""bird
of
youth
head
sees""",
"""hears
(every)
/
scribe
all
master
(lord)""",
"""king
sees
riverbank""",
"""woman
hears
storm""",
"""rope
makes
of
coil
father""",
"""mother
sees
hand""",
"""servant
sees
gate""",
"""god
great
mighty
gives
/""",
"""chisel
sees
man""",
"""sees
hill
owl""",
"""sees
woman
leaf
reed""",
"""mat
hears
stool
scribe
/""",
"""lake
king
makes""",
"""underground
youth
sees""",
"""pool
servant
sees""",
"""/
pellet
eats
father
grain""",
"""writes
authority
scribe""",
"""belly
animal
sees
man""",
"""love
peace
/
people
satisfy""",
"""beauty
king
/
speaks
good""",
"""servant
adze
gives""",
"""drinks
water
ripple
youth""",
"""sees
woman
owl""",
"""sees
hill
father
slope""",
"""storm
mother
hears""",
"""youth
man
loves
old""",
"""old
man
hears
youth""",
"""people
fire
fear""",
"""bird
scribe
sees
of
head""",
"""(give)
gives
god
conical
loaf""",
"""eats
bread
youth
of
loaf""",
"""god
sees
/
old
man
deity""",
"""mountain
king
sees""",
"""milk
servant
jar
gives""",
"""scribe
mother
sees""",
"""youth
pool
sees""",
"""king
rope
gives
tethering""",
"""twisted
sees
servant
flax""",
"""content
peace
god
/
(satisfied)
loves""",
"""sees
man
owl""",
"""hears
heart
mother""",
"""sickle
makes
father""",
"""/
scribe
scribe
writing
sees""",
"""ox
of
head
sees
youth""",
"""placenta
king
sees""",
"""god
gives
basket
with
handle""",
"""hill
sees
slope
servant""",
"""sees
man
star
old""",
"""/
loves
woman
beauty
good""",
"""rib
side
/
man
sees""",
"""makes
gate
king""",
"""people
/
see
god
deity""",
"""child
loves
mother
(youth)""",
"""king
scribe
hears""",
"""makes
god
fire""",
"""sees
servant
adze""",
"""loves
/
satisfy
youth
peace""",
"""backbone
sees
man""",
"""scribe
reed
sees
leaf""",
"""sees
board
senet
servant""",
"""sees
mother
house""",
"""plant
lotus
sees
scribe""",
"""youth
sees
jar""",
]

# %%
import torch
import random
import pandas as pd
import numpy as np
import os
from torch.utils.data import Dataset, DataLoader, random_split
from torch.optim import AdamW
from transformers import (
    BartTokenizer, 
    BartForConditionalGeneration, 
    get_linear_schedule_with_warmup
)
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction
from sklearn.metrics.pairwise import cosine_similarity
from tqdm import tqdm
import matplotlib.pyplot as plt
import seaborn as sns

# ==========================================
# 0. CONFIGURATION & DIRECTORIES
# ==========================================
MODEL_NAME = "facebook/bart-base"
MAX_LEN = 32
BATCH_SIZE = 16
EPOCHS = 100
LEARNING_RATE = 5e-5
SAVE_DIR = "./best_model_checkpoint"

if not os.path.exists(SAVE_DIR):
    os.makedirs(SAVE_DIR)

# ==========================================
# 1. DATA LOADING & PREPARATION
# ==========================================
# Assuming these variables exist in your environment. 
# Added fallbacks for script stability.

# Clean the inputs: Convert multiline strings to space-separated strings
original_shuffled = [s.replace("\n", " ").strip() for s in shuffled_sentences_raw]

# ==========================================
# 2. DATA AUGMENTATION
# ==========================================
print("Generating augmented data...")

def augment_data(ground_truth_list, num_augmentations=10):
    """
    Creates multiple shuffled versions of each ground truth sentence.
    """
    inputs = []
    targets = []
    
    for sentence in ground_truth_list:
        words = sentence.split()
        if len(words) <= 1:
            continue
            
        for _ in range(num_augmentations):
            shuffled_words = words.copy()
            random.shuffle(shuffled_words)
            inputs.append(" ".join(shuffled_words))
            targets.append(sentence)
            
    return inputs, targets

aug_inputs, aug_targets = augment_data(merged_ground_truth_sentences, num_augmentations=10)

all_inputs = aug_inputs + original_shuffled
all_targets = aug_targets + merged_ground_truth_sentences

df = pd.DataFrame({'input_text': all_inputs, 'target_text': all_targets})
print(f"Total dataset size after augmentation: {len(df)}")

# ==========================================
# 3. DATASET & DATALOADER
# ==========================================
class SentenceReconstructionDataset(Dataset):
    def __init__(self, tokenizer, data, max_len=32):
        self.tokenizer = tokenizer
        self.data = data
        self.max_len = max_len

    def __len__(self):
        return len(self.data)

    def __getitem__(self, index):
        source = str(self.data.iloc[index]['input_text'])
        target = str(self.data.iloc[index]['target_text'])

        source_tok = self.tokenizer(
            source, 
            max_length=self.max_len, 
            padding='max_length', 
            truncation=True, 
            return_tensors='pt'
        )

        target_tok = self.tokenizer(
            target, 
            max_length=self.max_len, 
            padding='max_length', 
            truncation=True, 
            return_tensors='pt'
        )

        # Labels for BART: shift happens internally, but we set -100 for padding
        labels = target_tok['input_ids'].flatten()
        labels[labels == self.tokenizer.pad_token_id] = -100

        return {
            'input_ids': source_tok['input_ids'].flatten(),
            'attention_mask': source_tok['attention_mask'].flatten(),
            'labels': labels
        }

# ==========================================
# 4. MODEL SETUP
# ==========================================
print(f"Loading {MODEL_NAME} model...")
tokenizer = BartTokenizer.from_pretrained(MODEL_NAME)
model = BartForConditionalGeneration.from_pretrained(MODEL_NAME)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

# Split Data
train_size = int(0.8 * len(df))
val_size = len(df) - train_size
train_indices, val_indices = random_split(range(len(df)), [train_size, val_size])

train_df = df.iloc[list(train_indices.indices)].reset_index(drop=True)
val_df = df.iloc[list(val_indices.indices)].reset_index(drop=True)

train_set = SentenceReconstructionDataset(tokenizer, train_df, max_len=MAX_LEN)
val_set = SentenceReconstructionDataset(tokenizer, val_df, max_len=MAX_LEN)

train_loader = DataLoader(train_set, batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(val_set, batch_size=BATCH_SIZE, shuffle=False)

optimizer = AdamW(model.parameters(), lr=LEARNING_RATE)

# ==========================================
# 5. METRICS HELPER
# ==========================================
try:
    from sentence_transformers import SentenceTransformer
    sim_model = SentenceTransformer('all-MiniLM-L6-v2')
    calc_cosine = True
except ImportError:
    print("sentence-transformers not installed. Cosine similarity will be skipped.")
    calc_cosine = False

def calculate_metrics(predictions, references):
    chencherry = SmoothingFunction()
    bleu_scores = [sentence_bleu([ref.split()], pred.split(), smoothing_function=chencherry.method1) 
                   for pred, ref in zip(predictions, references)]
    avg_bleu = np.mean(bleu_scores)

    avg_cosine = 0.0
    if calc_cosine:
        pred_embeddings = sim_model.encode(predictions)
        ref_embeddings = sim_model.encode(references)
        cos_sims = cosine_similarity(pred_embeddings, ref_embeddings).diagonal()
        avg_cosine = np.mean(cos_sims)
    
    return avg_bleu, avg_cosine

# ==========================================
# 6. TRAINING LOOP
# ==========================================
history = {'epoch': [], 'train_loss': [], 'val_loss': [], 'bleu': [], 'cosine': []}
best_val_loss = float('inf')

print("Starting training...")

for epoch in range(EPOCHS):
    # --- TRAIN ---
    model.train()
    total_train_loss = 0
    progress_bar = tqdm(train_loader, desc=f"Epoch {epoch+1}/{EPOCHS} [Train]")
    
    for batch in progress_bar:
        input_ids = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)
        labels = batch['labels'].to(device)

        outputs = model(input_ids=input_ids, attention_mask=attention_mask, labels=labels)
        loss = outputs.loss
        
        total_train_loss += loss.item()
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        progress_bar.set_postfix({'loss': f"{loss.item():.4f}"})

    avg_train_loss = total_train_loss / len(train_loader)

    # --- VALIDATION ---
    model.eval()
    total_val_loss = 0
    predictions = []
    references = []
    
    with torch.no_grad():
        for batch in val_loader:
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            labels = batch['labels'].to(device)

            outputs = model(input_ids=input_ids, attention_mask=attention_mask, labels=labels)
            total_val_loss += outputs.loss.item()
            
            generated_ids = model.generate(input_ids=input_ids, attention_mask=attention_mask, max_length=MAX_LEN)
            decoded_preds = tokenizer.batch_decode(generated_ids, skip_special_tokens=True)
            
            # Reset -100 to pad_token_id for proper decoding
            labels_to_decode = labels.clone()
            labels_to_decode[labels_to_decode == -100] = tokenizer.pad_token_id
            decoded_labels = tokenizer.batch_decode(labels_to_decode, skip_special_tokens=True)
            
            predictions.extend(decoded_preds)
            references.extend(decoded_labels)

    avg_val_loss = total_val_loss / len(val_loader)
    bleu, cosine = calculate_metrics(predictions, references)
    
    # --- CHECKPOINTING (BEST VERSION) ---
    if avg_val_loss < best_val_loss:
        best_val_loss = avg_val_loss
        print(f"--> New best model found! Saving to {SAVE_DIR}...")
        # Using HuggingFace's recommended method instead of legacy torch.save
        model.save_pretrained(SAVE_DIR)
        tokenizer.save_pretrained(SAVE_DIR)
    
    history['epoch'].append(epoch + 1)
    history['train_loss'].append(avg_train_loss)
    history['val_loss'].append(avg_val_loss)
    history['bleu'].append(bleu)
    history['cosine'].append(cosine)
    
    print(f"Epoch {epoch+1}: Train Loss: {avg_train_loss:.4f} | Val Loss: {avg_val_loss:.4f} | BLEU: {bleu:.4f}")

# ==========================================
# 7. RESULTS & VISUALIZATION
# ==========================================
# Load the best model for final evaluation/visualization
print("Loading best model for final reporting...")
model = BartForConditionalGeneration.from_pretrained(SAVE_DIR).to(device)

plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history['epoch'], history['train_loss'], label='Train Loss', marker='o')
plt.plot(history['epoch'], history['val_loss'], label='Val Loss', marker='o')
plt.title('Loss History')
plt.xlabel('Epoch'), plt.ylabel('Loss'), plt.legend(), plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(history['epoch'], history['bleu'], label='BLEU', marker='s', color='green')
if calc_cosine:
    plt.plot(history['epoch'], history['cosine'], label='Cosine', marker='^', color='purple')
plt.title('Metrics History')
plt.xlabel('Epoch'), plt.ylabel('Score'), plt.legend(), plt.grid(True)
plt.tight_layout()
plt.show()

print("\n=== SAMPLE RECONSTRUCTIONS (BEST MODEL) ===")
sample_indices = random.sample(range(len(predictions)), min(10, len(predictions)))
for i in sample_indices:
    print(f"Input:  {val_df.iloc[i]['input_text']}")
    print(f"Target: {references[i]}")
    print(f"Pred:   {predictions[i]}")
    print("-" * 30)

# Save logs
pd.DataFrame(history).to_csv('training_metrics.csv', index=False)
pd.DataFrame({'Input': val_df['input_text'], 'Target': references, 'Prediction': predictions}).to_csv('reconstruction_results.csv', index=False)
print(f"\nTraining complete. Best model saved in: {SAVE_DIR}")
# Out:
# 2026-02-04 14:22:07.090879: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1770214927.519205      24 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1770214927.648476      24 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1770214928.777638      24 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...
