# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
merged_sentences = [
    "great god gives life",
    "man opens door bolt",
    "father gives life ankh",
    "god sees people",
    "woman loves child life",
    "king rules city town",
    "strong god protects people",
    "man eats loaf bread",
    "woman hears sweet words",
    "god gives power king",
    "heart loves truth maat",
    "god opens horizon sky",
    "people live near river",
    "man plows fertile field",
    "king builds great temple",
    "god brings peace satisfied",
    "mother gives birth life",
    "man walks road town",
    "god controls storm sky",
    "people fear great god",
    "man enters house gate",
    "god hears prayers people",
    "king sits throne power",
    "god gives water life",
    "people cross river bank",
    "man carries basket handle",
    "woman drinks milk jar",
    "god lives eternal life",
    "man sees star sky",
    "people offer bread god",
    "god brings stability djed",
    "king holds crook power",
    "man hears owl night",
    "people live desert hill",
    "god emerges from horizon",
    "man returns home house",
    "god judges heart truth",
    "people praise mighty god",
    "king protects city people",
    "man fears snake bite",
    "god gives strength force",
    "people gather near temple",
    "man writes papyrus scroll",
    "god becomes scarab rebirth",
    "people love peace altar",
    "king rules land people",
    "man drinks water ripple",
    "god watches west horizon",
    "great god rules sky",
    "man hears god voice",
    "woman walks behind house",
    "king gives offering god",
    "people live near lake",
    "god creates mountain land",
    "man sees cobra snake",
    "woman opens jar milk",
    "god grants power throne",
    "people cross desert hill",
    "man carries coil rope",
    "god guards city gate",
    "king hears people prayers",
    "man eats conical loaf",
    "woman loves beautiful life",
    "god watches riverbank people",
    "people gather under sky",
    "man holds chisel stone",
    "god commands storm power",
    "king sits seat throne",
    "people fear horned viper",
    "man builds house brick",
    "god gives heart peace",
    "woman brings water jar",
    "people travel road west",
    "man sees horizon light",
    "god lives underground west",
    "king wears crown power",
    "people offer lotus plant",
    "man plows land field",
    "god hears voice man",
    "woman speaks sweet words",
    "people dwell city town",
    "man opens wooden door",
    "god protects soul ba",
    "king rules every land",
    "people praise god deity",
    "man walks hill slope",
    "woman sees star night",
    "god grants life people",
    "king builds stone temple",
    "people follow divine order",
    "man drinks from river",
    "god judges dead hearts",
    "woman sits stool mat",
    "people honor old man",
    "man writes sacred words",
    "god renews life cycle",
    "god lifts sky above",
    "man hears heart speak",
    "woman follows road town",
    "king commands servant people",
    "people gather by riverbank",
    "god shapes stone mountain",
    "man fears desert storm",
    "woman carries basket lord",
    "god gives ka spirit",
    "people build reed shelter",
    "man cuts plant sickle",
    "god opens hidden gate",
    "king leads people west",
    "man sees fire horizon",
    "woman offers bread altar",
    "god places star sky",
    "people rest under tree",
    "man binds rope knot",
    "god renews soul ba",
    "king guards house temple",
    "people drink sweet water",
    "man holds hoe field",
    "god commands life force",
    "woman walks face upon",
    "people honor divine maat",
    "man sees owl night",
    "god rests on throne",
    "king judges land people",
    "people follow lord every",
    "man climbs desert hill",
    "woman tends lotus plant",
    "god grants eternal stability",
    "people hear sacred words",
    "man opens city gate",
    "god watches from sky",
    "king wears sedge crown",
    "people cross winding road",
    "man shapes brick stone",
    "woman pours milk offering",
    "god unites heart truth",
    "god emerges from underground west",
    "man listens hear listen heart",
    "woman sits behind house gate",
    "king gives bread offering people",
    "people settle near riverbank town",
    "god raises pillar grandfather stability",
    "man carries jar water ripple",
    "woman sees beauty face upon",
    "god sends fire storm sky",
    "people travel beyond desert hill",
    "man shapes wood adze",
    "woman guards child life",
    "god grants power strength force",
    "king walks road city",
    "people rest beside lake",
    "man hears quail chick",
    "woman opens papyrus scroll writing",
    "god breathes life ankh",
    "people gather before temple gate",
    "man cuts rope tethering",
    "woman pours sweet milk",
    "god binds chaos snake",
    "king sits seated throne",
    "people honor venerated marrow",
    "man watches swallow sky",
    "woman tends grain pellet",
    "god sees through eye",
    "people live under protection",
    "man lifts stone pillar",
    "woman hears mother voice",
    "god commands order maat",
    "king rules by authority",
    "people cross bridge river",
    "man plants reed leaf",
    "woman walks toward horizon",
    "god renews time cycle",
    "people fear dark underground",
    "man drinks from vessel",
    "woman kneels peace altar",
    "god protects city town",
    "god rises beyond eastern horizon",
    "man hears sound water ripple",
    "woman walks beside river bank",
    "king grants land people",
    "people dwell near mountain",
    "god forms earth hill",
    "man fears horned viper snake",
    "woman holds child placenta",
    "god bestows royal authority",
    "people rest upon stool mat",
    "man tills soil plows",
    "god opens secret house",
    "king speaks words power",
    "man sees light sky",
    "woman brings offering temple",
    "god fixes stars heaven",
    "people settle fertile field",
    "man ties twisted flax",
    "god strengthens backbone stability",
    "king protects sacred shrine",
    "people drink from jar",
    "man grips forearm strength",
    "god grants lasting peace",
    "woman stands near gate",
    "people praise feather truth",
    "man hears desert silence",
    "god inhabits holy temple",
    "king commands city guard",
    "people follow divine path",
    "man walks toward west",
    "woman plants papyrus clump",
    "god preserves order maat",
    "people listen royal decree",
    "man lifts heavy stone",
    "woman pours water vessel",
    "god renews mortal life",
    "people cross open plain",
    "man writes signs writing",
    "woman kneels before god",
    "god guards eternal throne",
    "god opens gate horizon",
    "man hears voice god",
    "woman sits seated woman stool",
    "king rules town city",
    "people live by lake",
    "god gives life people",
    "woman drinks water ripple",
    "king holds power authority",
    "people cross river water",
    "god sees heart man",
    "man walks behind hill",
    "woman carries milk jar",
    "god grants strength strong",
    "people fear great storm",
    "man cuts grain sickle",
    "woman offers lotus offering",
    "god protects house gate",
    "people follow road west",
    "man hears owl",
    "woman sees beautiful face",
    "god emerges from hill",
    "king commands servant",
    "people gather temple",
    "man plants papyrus clump",
    "god gives peace satisfied",
    "scarab becomes life cycle renewal",
    "soul ba travels west underground",
    "ka spirit dwells within man",
    "feather maat weighs heart truth",
    "seated god rules eternal throne",
    "old man speaks wise words",
    "youth follows father authority",
    "mother feeds child milk jar",
    "mouth speaks words power authority",
    "eye sees face upon horizon",
    "hand holds ring power",
    "foot steps across riverbank",
    "owl cries during silent night",
    "snake coils near desert hill",
    "star shines above mountain peak",
    "storm breaks sky power force",
    "fire consumes offering altar peace",
    "pillar djed grants lasting stability",
    "lotus plant rises from water",
    "papyrus scroll holds sacred writing",
    "reed shelter stands near field",
    "vessel carries water ripple life",
    "gate opens toward city town",
    "road leads west horizon",
    "mountain guards sacred temple",
    "lake reflects star sky",
    "jar stores grain pellet food",
    "sickle cuts ripe field grain",
    "plows till earth repeatedly field",
    "seat throne symbolizes royal power",
    "great god gives life people",
    "man hear listen heart god",
    "woman walks road city town",
    "king gives offering temple god",
    "people live near river bank",
    "god opens house gate west",
    "man eats loaf of bread",
    "woman drinks water ripple jar",
    "king holds power strength force",
    "people cross road desert hill",
    "god sees heart of man",
    "man walks behind house gate",
    "woman carries basket with handle",
    "god grants peace content satisfied",
    "people honor father mother life",
    "man plows tills fertile field",
    "woman pours milk jar offering",
    "god protects city town people",
    "king sits seat throne power",
    "great king sees city town",
    "beautiful mother loves old man",
    "strong father makes brick house",
    "good god gives life heart",
    "mighty power becomes star sky",
    "great scribe makes papyrus scroll",
    "strong man plows great field",
    "every heart loves sweet peace",
    "good servant hears lord speak",
    "great river behind mountain hill",
    "beautiful woman loves lotus plant",
    "strong king makes great gate",
    "every town sees great god",
    "good father makes bread loaf",
    "mighty power becomes great strength",
    "great god gives birth youth",
    "strong father hears heart soul",
    "every man eats bread jar",
    "good scribe hears truth heart",
    "mighty king sees cobra snake",
    "beautiful youth becomes old man",
    "great riverbank upon water ripple",
    "strong forearm makes brick house",
    "every soul loves great peace",
    "good mother gives life youth",
    "seated god sees man face",
    "great horizon above desert hill",
    "strong power becomes stone brick",
    "every people love great king",
    "good heart makes beautiful life",
    "seated woman sees lotus plant sweet life",
    "cobra snake emerge desert hill mountain",
    "old man eat / drink / speak heart feather (truth/maat) soul (ba)",
    "seated god / king conical loaf (give) stone throne peace / satisfy",
    "quail chick behind / back lotus plant house city / town",
    "great / mighty cobra become god / deity he / king",
    "writing / scribe to do / make papyrus scroll book youth",
    "basket (lord / all) face / upon animal belly life (ankh) god",
    "beautiful / good face / upon sees horizon sky star",
    "strong hand cut stone brick city / town",
    "lord / every god hear man eat / drink / speak feather (truth/maat)",
    "life (ankh) emerge water ripple river field",
    "sweet milk jar face / upon peace / altar temple",
    "great / mighty cobra behind / back gate city / town",
    "beautiful / good youth sees great / big star sky",
    "father conical loaf (give) loaf of bread youth heart",
    "mother hear / listen beautiful / good heart soul (ba)",
    "strong backbone become great / mighty pillar / grandfather stability (djed)",
    "lord / every riverbank become great / big field plant",
    "seated god / king to do / make great / big storm fire",
    "writing / scribe hear / listen feather (truth/maat) heart life (ankh)",
    "he / king conical loaf (give) power great / mighty servant",
    "beautiful / good star above mountain hill slope",
    "man to do / make house brick stone city / town",
    "lord / every eye sees great / big fire horizon",
    "youth eat / drink / speak loaf of bread jar vessel",
    "master (lord) / all (every) hear / listen people heart feather (truth/maat)",
    "beautiful / good soul (ba) emerge behind / back sky horizon",
    "great / mighty stone become beautiful / good throne seat / throne",
    "strong club cut great / big road city / town",
    "lord / every father love beautiful / good youth mother",
    "beautiful / good god to do / make life (ankh) sweet peace / satisfy",
    "mother gives birth / begets beautiful / good youth life (ankh)",
    "writing / scribe sees book papyrus scroll hand",
    "great / mighty storm behind / back desert hill mountain",
    "he / king to do / make peace / satisfy lord / every town",
    "youth hear / listen great / big master (lord) / all (every) eat / drink / speak",
    "great / big house face / upon riverbank road city / town",
    "strong man plows (tills) great / big field grain / pellet",
    "beautiful / good lotus plant become sweet life (ankh)",
    "venerated / marrow father sees god / deity star sky",
    "great / big lake behind / back papyrus clump river",
    "horned viper emerge desert hill slope gate",
    "cobra snake fear great / mighty god / deity he / king",
    "seated woman hear / listen sweet heart soul (ba)",
    "strong forearm to do / make great / big brick house",
    "lord / every servant love great / big he / king lord",
    "life (ankh) emerge face / upon great / mighty horizon sky",
    "beautiful / good peace / altar above great / big hill slope",
    "writing / scribe to do / make beautiful / good papyrus scroll hand",
    "adze chisel to do / make stone",
    "authority strength / force gives birth / begets town",
    "basket with handle milk jar vessel",
    "door bolt gate stability (djed) house",
    "sedge (king) he / king above people",
    "swallow (great) sky above mountain hill",
    "head of bird eye sees star",
    "head of ox grain / pellet field",
    "twisted flax coil of rope riverbank",
    "senet board stool / mat seated man",
    "placenta animal belly gives birth / begets",
    "three fox skins folded cloth thing",
    "side / rib backbone pillar / grandfather strong",
    "thousand grain / pellet offering peace / altar",
    "sickle plows (tills) field life (ankh)",
    "hoe plows (repeated) road city / town",
    "reed shelter papyrus clump lake river",
    "reed leaf writing / scribe papyrus scroll",
    "tethering rope coil of rope gate",
    "ring stone vessel jars in rack",
    "horned viper snake fear desert hill",
    "owl head of bird sees bird",
    "foot road riverbank town city / town",
    "single stroke stroke (plural marker) thing",
    "ka (spirit) soul (ba) life (ankh) god",
    "west mountain horizon sky peace / satisfy",
    "venerated / marrow father mother beautiful / good",
    "negation (no/not) fear great / mighty god",
    "opens / exists (or is found) gate road",
    "storm fire sky great / mighty mountain",
    "swallow (great) emerge horizon water ripple",
    "animal belly placenta gives birth / begets life",
    "basket (lord / all) thing beautiful / good",
    "strength / force power authority he / king",
    "to return / retreat behind / back gate",
    "face / upon hill slope brick house",
    "heart love beautiful / good lotus plant",
    "mouth eat / drink / speak bread jar",
    "forearm strong hand to do / make",
    "chisel adze stone seat / throne great",
    "club strength / force fear cobra snake",
    "underground lake water ripple snake emerge",
    "seated man (i / me) scribe book",
    "seated woman love lotus plant peace",
    "sedge (king) authority great / mighty power",
    "conical loaf (give) offering peace / altar",
    "coil of rope tethering rope riverbank",
    "horizon star sky mountain desert hill",
    "old man venerated / marrow father soul",
    "quail chick head of bird horizon",
    "scarab / become life (ankh) great / mighty star",
    "river water ripple lake papyrus clump",
    "sky above mountain desert hill slope",
    "he / king seat / throne great / big",
    "servant to do / make brick house",
    "mother gives birth / begets youth life",
    "father heart love beautiful / good youth",
    "old man hear / listen feather (truth/maat)",
    "scribe writing / scribe papyrus scroll hand",
    "god / deity life (ankh) heart soul",
    "eye sees face / upon god / deity",
    "mouth eat / drink / speak bread loaf",
    "loaf of bread offering peace / altar",
    "vessel jar milk jar peace / satisfy",
    "road city / town gate town town",
    "foot road behind / back brick house",
    "hand to do / make thing thing",
    "field plant grain / pellet hoe plows",
    "sickle plows (tills) great / mighty field",
    "stability (djed) pillar / grandfather power authority",
    "authority strength / force master (lord) / all (every)",
    "soul (ba) ka (spirit) life (ankh) god",
    "feather (truth/maat) heart peace / content (satisfied)",
    "storm fire sky mountain hill slope",
    "swallow (great) emerge horizon sky star",
    "quail chick head of bird horizon sky",
    "sedge (king) people city / town town",
    "basket (lord / all) thing great / big",
    "adze chisel stone brick house city",
    "forearm strong to do / make thing",
    "twisted flax rope coil of rope",
    "tethering rope ring stone vessel jars",
    "thousand offering peace / altar god / deity",
    "side / rib backbone strength / force power",
    "underground snake emerge water ripple river",
    "west mountain horizon peace / satisfy heart",
    "venerated / marrow old man soul (ba)",
    "opens / exists (or is found) road town",
    "like / as (or example) god / deity",
    "animal belly placenta gives birth / begets",
    "reed shelter lake papyrus clump river",
    "lotus plant sweet beautiful / good life",
    "adze chisel stone seat / throne great / big",
    "venerated / marrow father hear heart soul (ba)",
    "authority strength / force power he / king great / mighty",
    "lake riverbank papyrus clump river swallow",
    "three fox skins folded cloth thing beautiful / good",
    "animal belly gives birth / begets youth life (ankh)",
    "horizon star sky above mountain",
    "basket with handle milk jar vessel peace / altar",
    "door bolt gate stability (djed) house city / town",
    "sedge (king) he / king great / mighty authority people",
    "sickle plows (tills) grain / pellet field strong",
    "swallow (great) emerge horizon sky beautiful / good",
    "horned viper snake fear desert hill slope",
    "senet board stool / mat seated man peace / satisfy",
    "thousand offering peace / altar god / deity great / mighty",
    "writing / scribe book papyrus scroll hand scribe",
    "mouth eat / drink / speak loaf of bread jar vessel",
    "youth become old man life (ankh) venerated / marrow",
    "lotus plant sweet beautiful / good life (ankh) heart",
    "side / rib backbone strong power stability (djed)",
    "coil of rope tethering rope basket with handle hand",
    "underground snake river water ripple emerge",
    "west mountain desert hill slope horizon",
    "opens / exists (or is found) gate road town city / town",
    "to return / retreat behind / back gate city / town house",
    "ka (spirit) soul (ba) life (ankh) god / deity great / mighty",
    "head of ox grain / pellet field hoe strong",
    "head of bird eye sees star sky",
    "reed leaf writing / scribe hand to do / make book",
    "reed shelter lake papyrus clump river lotus plant",
    "placenta animal belly gives birth / begets youth life",
    "brick house city / town town great / big",
    "hand to do / make thing beautiful / good great / mighty",
    "forearm strong hand to do / make brick",
    "storm fire sky great / mighty fear",
    "people hear / listen authority he / king great",
    "face / on (upon) hill slope brick house town",
    "like / as (or example) god / deity power strength / force",
    "conical loaf (give) loaf of bread heart peace / content (satisfied)",
    "jar vessel jars in rack milk jar peace / altar",
    "ring stone vessel jars in rack great",
    "single stroke stroke (plural marker) thing great / big",
    "beautiful / good face / upon soul (ba) life (ankh) god",
    "master (lord) / all (every) servant hear / listen authority king",
    "authority power great / mighty strength / force strong",
    "father mother gives birth / begets youth life",
    "heart peace / content (satisfied) soul (ba) life (ankh) god",
    "horizon above desert hill mountain sky",
    "stability (djed) pillar / grandfather house city / town great",
    "adze chisel to do / make stool / mat stone",
    "basket with handle jars in rack milk jar vessel",
    "door bolt gate house stability (djed) pillar / grandfather",
    "sedge (king) authority he / king master (lord) / all (every) town",
    "quail chick head of bird swallow (great) sky horizon",
    "three fox skins folded cloth thing beautiful / good servant",
    "side / rib animal belly placenta gives birth / begets youth",
    "thousand grain / pellet offering peace / altar heart",
    "sickle plows (tills) field river water ripple road",
    "hoe plows (repeated) road mountain desert hill slope",
    "reed shelter papyrus clump lake riverbank swallow (great)",
    "reed leaf writing / scribe papyrus scroll book hand",
    "tethering rope coil of rope basket (lord / all) hand",
    "ring stone vessel jar jars in rack stone",
    "horned viper snake desert hill slope desert hare (to be)",
    "owl head of bird sees seated woman beautiful / good",
    "foot road town city / town gate riverbank",
    "single stroke stroke (plural marker) thing people city / town",
    "ka (spirit) soul (ba) heart life (ankh) god / deity",
    "west mountain horizon sky star above above",
    "venerated / marrow father mother heart peace / satisfy life",
    "negation (no/not) fear great / mighty god / deity strength / force",
    "opens / exists (or is found) gate road riverbank field",
    "storm fire sky mountain hill slope horizon",
    "swallow (great) emerge horizon sky beautiful / good life (ankh)",
    "animal belly placenta gives birth / begets youth life (ankh)",
    "basket (lord / all) thing beautiful / good life (ankh) god",
    "strength / force power authority he / king strong pillar / grandfather",
    "to return / retreat behind / back gate town road",
    "face / on (upon) hill slope brick house brick city / town",
    "heart love beautiful / good lotus plant sweet peace / satisfy",
    "mouth eat / drink / speak bread loaf vessel jar",
    "forearm strong hand to do / make stone brick",
    "chisel adze stone seat / throne great / big mighty",
    "club strength / force fear cobra snake snake",
    "underground lake water ripple snake emerge desert",
    "seated man (i / me) book writing / scribe hand scribe",
    "seated woman love lotus plant peace / satisfy life (ankh)",
    "sedge (king) authority great / mighty power he / king king",
    "conical loaf (give) offering peace / altar god / deity life (ankh)",
    "coil of rope tethering rope riverbank lake water ripple",
    "horizon star sky mountain desert hill hill",
    "old man venerated / marrow father heart soul (ba)",
    "quail chick head of bird horizon sky star",
    "papyrus scroll book writing / scribe hand single stroke",
    "grain / pellet field hoe plows (tills) field",
    "stability (djed) pillar / grandfather house city / town town",
    "father mother youth life (ankh) heart soul (ba)",
    "sky above mountain desert hill slope field",
    "adze chisel cut stone brick city / town",
    "senet board stool / mat seated woman life (ankh)",
    "venerated / marrow mother heart soul (ba) peace / satisfy",
    "lotus plant sweet life (ankh) heart god / deity",
    "quail chick head of bird sky star horizon",
    "three fox skins folded cloth thing master (lord) / all (every)",
    "animal belly placenta gives birth / begets beautiful / good youth",
    "thousand offering peace / altar god / deity soul (ba)",
    "sickle plows (tills) field grain / pellet water ripple",
    "hoe plows (repeated) road city / town house brick",
    "reed shelter lake papyrus clump swallow (great) sky",
    "reed leaf writing / scribe papyrus scroll hand scribe",
    "tethering rope coil of rope basket with handle vessel",
    "ring stone vessel jars in rack stone throne",
    "horned viper snake fear desert hill mountain hill",
    "owl head of bird sees seated man heart",
    "foot road town gate riverbank water ripple",
    "single stroke stroke (plural marker) thing people strength / force",
    "ka (spirit) soul (ba) life (ankh) heart peace / satisfy",
    "west mountain horizon sky star above hill",
    "venerated / marrow father mother youth life (ankh) beautiful / good",
    "negation (no/not) fear storm fire great / mighty god / deity",
    "opens / exists (or is found) gate road city / town town",
    "swallow (great) emerge horizon sky star above",
    "sedge (king) authority he / king power strength / force",
    "basket (lord / all) thing beautiful / good life (ankh) heart",
    "to return / retreat behind / back gate house city / town",
    "face / on (upon) hill slope brick house stone",
    "mouth eat / drink / speak loaf of bread milk jar",
    "forearm strong hand to do / make thing great / mighty",
    "chisel adze stone brick house city / town town",
    "club strength / force fear cobra snake desert hill",
    "underground lake water ripple snake emerge horizon",
    "seated man (i / me) scribe book papyrus scroll",
    "seated woman love lotus plant sweet peace / satisfy",
    "sedge (king) he / king authority power great / mighty",
    "conical loaf (give) offering peace / altar life (ankh) god / deity",
    "coil of rope tethering rope riverbank road city / town",
    "old man venerated / marrow father soul (ba) ka (spirit)",
    "grain / pellet field hoe plows (tills) field plant",
    "stability (djed) pillar / grandfather house city / town great / mighty",
    "father mother gives birth / begets youth life (ankh) heart",
    "sky above mountain desert hill slope horizon",
    "writing / scribe book papyrus scroll hand to do / make",
    "great / mighty storm fire sky mountain hill slope",
    "beautiful / good face / upon soul (ba) life (ankh) god / deity",
    "master (lord) / all (every) servant hear / listen authority he / king",
    "authority power strength / force strong pillar / grandfather stability (djed)",
    "horizon star sky above desert hill mountain",
    "quail chick head of bird horizon sky star above",
    "adze stone brick house city / town",
    "authority power master (lord) / all (every) servant",
    "basket (lord / all) thing beautiful / good life (ankh)",
    "conical loaf (give) bread heart peace / satisfy",
    "door bolt gate house city / town town",
    "eye sees star sky horizon sky",
    "father love youth heart beautiful / good",
    "field grain / pellet hoe plows (tills) field",
    "forearm strong to do / make stone brick",
    "god / deity ka (spirit) soul (ba) heart life (ankh)",
    "hand to do / make thing stone throne",
    "head of bird owl sees snake emerge",
    "he / king sedge (king) authority power strength / force",
    "horned viper snake fear great / mighty god / deity",
    "jar vessel milk jar offering peace / altar",
    "lake water ripple papyrus clump reed shelter",
    "lotus plant sweet life (ankh) soul (ba) heart",
    "mother father gives birth / begets beautiful / good youth",
    "mouth eat / drink / speak bread jar vessel",
    "old man venerated / marrow heart peace / satisfy",
    "opens / exists (or is found) gate road city / town",
    "papyrus scroll book writing / scribe hand scribe",
    "people hear / listen authority he / king king",
    "pillar / grandfather stability (djed) strength / force power authority",
    "quail chick swallow (great) sky above mountain",
    "reed leaf reed shelter lake river water ripple",
    "ring stone vessel jars in rack stone",
    "scribe hear / listen feather (truth/maat) heart soul (ba)",
    "seated woman love lotus plant sweet life (ankh)",
    "senet board stool / mat seated man house",
    "sickle plows (tills) field grain / pellet plant",
    "side / rib backbone strong stability (djed) pillar / grandfather",
    "sky horizon star above mountain desert hill",
    "snake emerge desert hill slope water ripple",
    "soul (ba) ka (spirit) emerge horizon sky star",
    "stability (djed) pillar / grandfather house city / town stone",
    "storm fire sky fear great / mighty god / deity",
    "strength / force power authority he / king people",
    "tethering rope coil of rope hand to do / make",
    "thousand offering peace / altar bread milk jar",
    "to return / retreat behind / back gate town",
    "underground lake water ripple snake emerge desert hill",
    "venerated / marrow father mother youth life (ankh)",
    "vessel jar milk jar peace / satisfy god / deity",
    "west mountain horizon sky peace / satisfy heart",
    "writing / scribe papyrus scroll book hand single stroke",
    "youth become old man venerated / marrow life (ankh)",
]

# %%
shuffled_raw = [
"""gives
god
life
great""",
"""bolt
door
man
opens""",
"""gives
ankh
life
father""",
"""god
sees
people""",
"""loves
child
life
woman""",
"""town
city
king
rules""",
"""strong
people
protects
god""",
"""man
loaf
bread
eats""",
"""sweet
hears
words
woman""",
"""king
god
gives
power""",
"""truth
heart
maat
loves""",
"""horizon
sky
opens
god""",
"""people
river
live
near""",
"""field
plows
fertile
man""",
"""great
temple
builds
king""",
"""god
brings
satisfied
peace""",
"""life
mother
birth
gives""",
"""walks
town
road
man""",
"""controls
sky
god
storm""",
"""god
great
fear
people""",
"""man
enters
house
gate""",
"""god
prayers
people
hears""",
"""king
power
throne
sits""",
"""gives
life
water
god""",
"""river
bank
people
cross""",
"""basket
man
carries
handle""",
"""drinks
jar
woman
milk""",
"""life
eternal
lives
god""",
"""sees
sky
man
star""",
"""god
offer
people
bread""",
"""god
brings
stability
djed""",
"""crook
king
power
holds""",
"""man
night
owl
hears""",
"""people
live
desert
hill""",
"""emerges
horizon
god
from""",
"""returns
home
man
house""",
"""judges
heart
truth
god""",
"""praise
people
mighty
god""",
"""king
city
protects
people""",
"""fears
man
bite
snake""",
"""force
gives
strength
god""",
"""temple
gather
people
near""",
"""papyrus
writes
man
scroll""",
"""rebirth
becomes
scarab
god""",
"""altar
people
peace
love""",
"""rules
king
people
land""",
"""water
man
ripple
drinks""",
"""horizon
watches
west
god""",
"""god
rules
great
sky""",
"""voice
man
hears
god""",
"""walks
behind
house
woman""",
"""god
gives
offering
king""",
"""live
lake
near
people""",
"""god
land
mountain
creates""",
"""man
cobra
snake
sees""",
"""milk
woman
jar
opens""",
"""god
throne
grants
power""",
"""people
cross
desert
hill""",
"""carries
coil
rope
man""",
"""city
gate
guards
god""",
"""prayers
king
people
hears""",
"""eats
conical
loaf
man""",
"""life
beautiful
woman
loves""",
"""watches
people
god
riverbank""",
"""people
gather
sky
under""",
"""stone
man
chisel
holds""",
"""storm
commands
god
power""",
"""sits
seat
king
throne""",
"""viper
fear
horned
people""",
"""man
brick
builds
house""",
"""gives
god
heart
peace""",
"""water
brings
jar
woman""",
"""travel
west
people
road""",
"""horizon
light
man
sees""",
"""underground
god
west
lives""",
"""power
king
wears
crown""",
"""lotus
plant
offer
people""",
"""plows
field
land
man""",
"""hears
voice
man
god""",
"""woman
sweet
speaks
words""",
"""city
people
town
dwell""",
"""wooden
man
door
opens""",
"""god
soul
protects
ba""",
"""king
land
rules
every""",
"""god
deity
people
praise""",
"""slope
hill
man
walks""",
"""sees
night
woman
star""",
"""grants
god
life
people""",
"""builds
temple
stone
king""",
"""order
divine
people
follow""",
"""from
man
river
drinks""",
"""hearts
god
dead
judges""",
"""mat
stool
sits
woman""",
"""man
honor
people
old""",
"""man
sacred
words
writes""",
"""god
cycle
life
renews""",
"""sky
god
lifts
above""",
"""heart
speak
hears
man""",
"""follows
town
road
woman""",
"""people
commands
king
servant""",
"""by
gather
riverbank
people""",
"""mountain
shapes
god
stone""",
"""fears
man
storm
desert""",
"""carries
woman
lord
basket""",
"""ka
god
spirit
gives""",
"""build
shelter
reed
people""",
"""sickle
man
cuts
plant""",
"""gate
opens
god
hidden""",
"""people
king
leads
west""",
"""horizon
sees
fire
man""",
"""offers
altar
woman
bread""",
"""sky
places
god
star""",
"""people
tree
under
rest""",
"""binds
man
rope
knot""",
"""renews
soul
ba
god""",
"""house
temple
guards
king""",
"""drink
sweet
people
water""",
"""field
man
holds
hoe""",
"""commands
force
god
life""",
"""upon
face
walks
woman""",
"""maat
divine
people
honor""",
"""owl
man
night
sees""",
"""god
throne
on
rests""",
"""judges
king
land
people""",
"""follow
every
people
lord""",
"""desert
climbs
man
hill""",
"""lotus
plant
woman
tends""",
"""stability
god
grants
eternal""",
"""words
sacred
people
hear""",
"""man
city
opens
gate""",
"""sky
from
watches
god""",
"""king
wears
sedge
crown""",
"""winding
cross
road
people""",
"""man
stone
brick
shapes""",
"""milk
pours
offering
woman""",
"""god
unites
truth
heart""",
"""from
west
emerges
god
underground""",
"""listen
listens
heart
man
hear""",
"""gate
behind
house
sits
woman""",
"""people
gives
offering
bread
king""",
"""town
settle
riverbank
near
people""",
"""god
stability
raises
pillar
grandfather""",
"""jar
water
man
carries
ripple""",
"""woman
upon
beauty
sees
face""",
"""sky
fire
sends
god
storm""",
"""people
hill
beyond
desert
travel""",
"""man
wood
shapes
adze""",
"""woman
life
child
guards""",
"""strength
power
force
god
grants""",
"""road
walks
city
king""",
"""lake
beside
people
rest""",
"""hears
quail
chick
man""",
"""writing
papyrus
opens
woman
scroll""",
"""god
ankh
life
breathes""",
"""gather
before
people
gate
temple""",
"""rope
cuts
tethering
man""",
"""sweet
milk
woman
pours""",
"""binds
snake
chaos
god""",
"""seated
throne
sits
king""",
"""people
honor
venerated
marrow""",
"""man
watches
swallow
sky""",
"""grain
tends
woman
pellet""",
"""through
god
sees
eye""",
"""people
live
protection
under""",
"""man
stone
pillar
lifts""",
"""voice
hears
mother
woman""",
"""god
order
maat
commands""",
"""rules
king
authority
by""",
"""river
bridge
people
cross""",
"""plants
man
reed
leaf""",
"""toward
horizon
woman
walks""",
"""god
time
renews
cycle""",
"""fear
dark
people
underground""",
"""from
man
drinks
vessel""",
"""peace
woman
kneels
altar""",
"""god
town
protects
city""",
"""beyond
god
horizon
rises
eastern""",
"""ripple
man
hears
water
sound""",
"""woman
walks
bank
beside
river""",
"""land
king
people
grants""",
"""near
mountain
dwell
people""",
"""hill
forms
earth
god""",
"""snake
horned
man
viper
fears""",
"""woman
placenta
holds
child""",
"""god
royal
authority
bestows""",
"""people
mat
rest
stool
upon""",
"""plows
tills
man
soil""",
"""opens
house
secret
god""",
"""speaks
power
king
words""",
"""sees
light
sky
man""",
"""temple
offering
woman
brings""",
"""stars
heaven
god
fixes""",
"""settle
field
fertile
people""",
"""man
ties
twisted
flax""",
"""strengthens
stability
god
backbone""",
"""sacred
king
shrine
protects""",
"""jar
from
drink
people""",
"""grips
man
forearm
strength""",
"""grants
peace
lasting
god""",
"""gate
stands
near
woman""",
"""praise
truth
feather
people""",
"""man
hears
silence
desert""",
"""temple
inhabits
god
holy""",
"""guard
city
commands
king""",
"""path
divine
follow
people""",
"""walks
man
toward
west""",
"""papyrus
plants
woman
clump""",
"""god
order
preserves
maat""",
"""decree
people
listen
royal""",
"""stone
heavy
lifts
man""",
"""woman
water
vessel
pours""",
"""life
renews
god
mortal""",
"""plain
cross
people
open""",
"""man
signs
writing
writes""",
"""woman
god
kneels
before""",
"""guards
throne
eternal
god""",
"""gate
opens
horizon
god""",
"""hears
man
voice
god""",
"""seated
woman
sits
stool
woman""",
"""town
city
rules
king""",
"""live
people
by
lake""",
"""god
gives
people
life""",
"""woman
drinks
water
ripple""",
"""king
holds
power
authority""",
"""people
cross
water
river""",
"""god
man
sees
heart""",
"""hill
behind
man
walks""",
"""carries
jar
woman
milk""",
"""strength
strong
god
grants""",
"""people
fear
storm
great""",
"""grain
cuts
sickle
man""",
"""lotus
woman
offering
offers""",
"""protects
gate
god
house""",
"""follow
west
people
road""",
"""man
hears
owl""",
"""woman
face
beautiful
sees""",
"""from
emerges
hill
god""",
"""king
servant
commands""",
"""people
temple
gather""",
"""papyrus
clump
man
plants""",
"""gives
peace
god
satisfied""",
"""becomes
life
scarab
renewal
cycle""",
"""soul
west
travels
underground
ba""",
"""dwells
within
man
spirit
ka""",
"""feather
heart
weighs
maat
truth""",
"""seated
rules
god
throne
eternal""",
"""man
wise
words
old
speaks""",
"""authority
youth
father
follows""",
"""feeds
jar
milk
mother
child""",
"""authority
words
power
mouth
speaks""",
"""eye
sees
face
horizon
upon""",
"""holds
power
hand
ring""",
"""foot
steps
riverbank
across""",
"""cries
night
during
owl
silent""",
"""hill
snake
desert
coils
near""",
"""mountain
star
above
shines
peak""",
"""power
force
storm
breaks
sky""",
"""fire
peace
altar
offering
consumes""",
"""stability
grants
djed
pillar
lasting""",
"""lotus
plant
water
rises
from""",
"""scroll
writing
holds
papyrus
sacred""",
"""reed
shelter
field
stands
near""",
"""carries
water
ripple
life
vessel""",
"""town
opens
city
gate
toward""",
"""west
road
leads
horizon""",
"""mountain
guards
sacred
temple""",
"""sky
star
reflects
lake""",
"""food
jar
stores
grain
pellet""",
"""sickle
field
grain
ripe
cuts""",
"""till
plows
field
repeatedly
earth""",
"""power
symbolizes
throne
seat
royal""",
"""people
life
god
great
gives""",
"""listen
man
hear
heart
god""",
"""woman
town
city
road
walks""",
"""offering
gives
god
king
temple""",
"""people
near
river
live
bank""",
"""opens
house
west
god
gate""",
"""bread
man
of
loaf
eats""",
"""drinks
water
woman
ripple
jar""",
"""holds
power
force
strength
king""",
"""people
cross
hill
road
desert""",
"""heart
god
sees
man
of""",
"""behind
man
gate
walks
house""",
"""basket
with
woman
carries
handle""",
"""god
grants
satisfied
peace
content""",
"""life
honor
mother
father
people""",
"""tills
plows
man
fertile
field""",
"""woman
milk
pours
jar
offering""",
"""god
city
protects
town
people""",
"""king
throne
seat
power
sits""",
"""sees
town
great
city
king""",
"""loves
beautiful
mother
man
old""",
"""makes
father
house
strong
brick""",
"""gives
god
heart
life
good""",
"""becomes
sky
star
power
mighty""",
"""scroll
makes
scribe
papyrus
great""",
"""man
strong
plows
great
field""",
"""every
peace
heart
sweet
loves""",
"""servant
lord
hears
good
speak""",
"""hill
mountain
great
behind
river""",
"""woman
plant
loves
beautiful
lotus""",
"""strong
gate
makes
king
great""",
"""sees
great
town
god
every""",
"""good
bread
father
loaf
makes""",
"""mighty
great
becomes
strength
power""",
"""birth
gives
great
god
youth""",
"""father
soul
hears
heart
strong""",
"""eats
jar
every
man
bread""",
"""heart
good
scribe
truth
hears""",
"""king
mighty
snake
sees
cobra""",
"""man
becomes
youth
old
beautiful""",
"""great
ripple
riverbank
upon
water""",
"""makes
strong
house
brick
forearm""",
"""every
peace
loves
great
soul""",
"""good
mother
life
gives
youth""",
"""sees
face
god
man
seated""",
"""desert
horizon
above
great
hill""",
"""strong
stone
brick
power
becomes""",
"""every
great
love
king
people""",
"""life
beautiful
makes
good
heart""",
"""woman
plant
sweet
life
seated
lotus
sees""",
"""mountain
snake
desert
hill
emerge
cobra""",
"""old
heart
soul
man
(truth/maat)
speak
drink
/
feather
(ba)
/
eat""",
"""satisfy
/
seated
/
king
(give)
throne
peace
stone
god
loaf
conical""",
"""town
house
/
plant
lotus
behind
/
chick
city
back
quail""",
"""/
he
god
king
mighty
/
become
great
deity
cobra
/""",
"""to
scribe
/
scroll
book
/
writing
make
do
papyrus
youth""",
"""(ankh)
basket
face
/
animal
upon
life
/
belly
all)
god
(lord""",
"""upon
sky
star
beautiful
good
face
/
horizon
/
sees""",
"""city
brick
strong
cut
hand
/
town
stone""",
"""(truth/maat)
/
every
feather
god
/
/
hear
eat
lord
man
speak
drink""",
"""emerge
(ankh)
water
life
ripple
field
river""",
"""altar
/
peace
upon
milk
/
sweet
temple
jar
face""",
"""gate
cobra
city
town
/
/
back
behind
great
/
mighty""",
"""great
youth
big
/
sees
/
star
sky
good
beautiful""",
"""bread
heart
loaf
youth
(give)
of
conical
father
loaf""",
"""hear
soul
/
listen
mother
good
beautiful
/
(ba)
heart""",
"""pillar
become
backbone
/
(djed)
mighty
great
/
grandfather
strong
stability""",
"""every
plant
field
become
lord
riverbank
great
big
/
/""",
"""seated
/
fire
storm
make
big
king
do
great
/
to
/
god""",
"""writing
scribe
/
listen
life
feather
(truth/maat)
hear
heart
(ankh)
/""",
"""mighty
/
he
loaf
great
king
conical
(give)
/
servant
power""",
"""good
slope
above
star
mountain
hill
beautiful
/""",
"""brick
to
make
town
/
/
stone
house
man
city
do""",
"""/
eye
great
/
big
horizon
every
fire
sees
lord""",
"""of
loaf
vessel
jar
/
/
youth
bread
speak
eat
drink""",
"""all
people
(lord)
(truth/maat)
/
hear
listen
/
master
(every)
feather
heart""",
"""back
soul
sky
(ba)
beautiful
emerge
/
/
behind
horizon
good""",
"""/
become
stone
great
throne
/
seat
mighty
beautiful
good
throne
/""",
"""/
city
road
/
big
great
town
club
strong
cut""",
"""good
beautiful
/
every
lord
youth
mother
father
love
/""",
"""do
good
peace
/
god
/
beautiful
satisfy
life
make
(ankh)
/
sweet
to""",
"""life
beautiful
gives
good
mother
/
youth
(ankh)
birth
/
begets""",
"""writing
papyrus
hand
scroll
book
sees
/
scribe""",
"""behind
mighty
mountain
/
hill
desert
storm
great
back
/""",
"""/
town
/
peace
king
he
to
/
do
every
lord
/
make
satisfy""",
"""great
youth
(lord)
master
/
/
speak
eat
all
/
drink
listen
hear
/
big
/
(every)""",
"""riverbank
face
great
city
/
big
upon
house
/
town
road
/""",
"""big
grain
field
/
strong
man
/
pellet
(tills)
great
plows""",
"""beautiful
/
lotus
good
sweet
plant
become
(ankh)
life""",
"""star
venerated
god
sees
sky
/
father
/
deity
marrow""",
"""back
papyrus
behind
great
river
lake
big
/
clump
/""",
"""desert
viper
slope
hill
horned
emerge
gate""",
"""/
mighty
great
fear
snake
/
god
king
cobra
deity
he
/""",
"""woman
listen
sweet
soul
heart
/
seated
hear
(ba)""",
"""house
brick
/
forearm
great
/
make
do
strong
to
big""",
"""lord
servant
/
big
every
he
/
lord
great
king
/
love""",
"""emerge
life
face
(ankh)
/
horizon
upon
sky
/
great
mighty""",
"""great
beautiful
slope
/
peace
above
/
/
altar
good
hill
big""",
"""hand
beautiful
writing
scroll
to
papyrus
good
/
scribe
/
make
/
do""",
"""do
adze
/
stone
make
chisel
to""",
"""/
town
gives
birth
begets
authority
strength
/
force""",
"""basket
milk
jar
with
handle
vessel""",
"""stability
door
gate
(djed)
house
bolt""",
"""he
king
(king)
people
sedge
/
above""",
"""swallow
(great)
hill
sky
mountain
above""",
"""head
bird
eye
star
sees
of""",
"""head
/
pellet
grain
ox
of
field""",
"""flax
coil
twisted
riverbank
rope
of""",
"""/
seated
senet
stool
board
mat
man""",
"""animal
gives
/
placenta
birth
belly
begets""",
"""cloth
thing
folded
fox
three
skins""",
"""pillar
strong
/
/
side
backbone
grandfather
rib""",
"""offering
grain
peace
/
/
altar
pellet
thousand""",
"""life
field
(ankh)
plows
(tills)
sickle""",
"""road
city
town
plows
(repeated)
/
hoe""",
"""reed
lake
river
shelter
clump
papyrus""",
"""writing
leaf
scroll
papyrus
reed
scribe
/""",
"""coil
rope
tethering
of
gate
rope""",
"""rack
in
jars
ring
vessel
stone""",
"""viper
snake
horned
hill
desert
fear""",
"""head
bird
of
owl
sees
bird""",
"""city
town
foot
town
riverbank
road
/""",
"""thing
stroke
single
(plural
marker)
stroke""",
"""(ba)
(ankh)
(spirit)
god
ka
soul
life""",
"""peace
satisfy
mountain
horizon
sky
/
west""",
"""father
good
mother
/
marrow
venerated
/
beautiful""",
"""mighty
great
negation
(no/not)
fear
/
god""",
"""opens
is
exists
(or
/
road
gate
found)""",
"""great
/
sky
storm
mountain
fire
mighty""",
"""horizon
water
ripple
(great)
emerge
swallow""",
"""life
belly
/
gives
birth
begets
placenta
animal""",
"""all)
/
good
/
(lord
beautiful
basket
thing""",
"""king
authority
/
power
/
strength
force
he""",
"""to
gate
/
behind
retreat
return
/
back""",
"""upon
slope
/
brick
hill
face
house""",
"""plant
love
/
heart
lotus
beautiful
good""",
"""bread
eat
mouth
speak
jar
drink
/
/""",
"""do
strong
/
make
forearm
to
hand""",
"""seat
adze
great
/
chisel
throne
stone""",
"""snake
cobra
force
club
strength
fear
/""",
"""water
snake
ripple
emerge
lake
underground""",
"""man
scribe
book
seated
me)
/
(i""",
"""seated
plant
woman
love
lotus
peace""",
"""mighty
great
authority
(king)
/
sedge
power""",
"""altar
peace
conical
loaf
/
(give)
offering""",
"""coil
rope
rope
tethering
of
riverbank""",
"""hill
mountain
star
sky
horizon
desert""",
"""soul
father
old
/
venerated
marrow
man""",
"""head
horizon
bird
of
quail
chick""",
"""life
(ankh)
star
/
scarab
become
mighty
great
/""",
"""papyrus
river
lake
ripple
water
clump""",
"""mountain
desert
slope
hill
above
sky""",
"""/
big
/
seat
king
great
/
throne
he""",
"""house
/
to
do
brick
servant
make""",
"""birth
gives
life
mother
youth
/
begets""",
"""youth
heart
love
/
beautiful
father
good""",
"""hear
/
old
(truth/maat)
feather
listen
man""",
"""/
hand
scribe
writing
scroll
scribe
papyrus""",
"""god
(ankh)
life
heart
soul
deity
/""",
"""/
god
eye
/
upon
deity
face
sees""",
"""/
drink
mouth
bread
loaf
speak
/
eat""",
"""of
bread
offering
/
loaf
peace
altar""",
"""vessel
jar
satisfy
jar
milk
peace
/""",
"""town
city
/
town
road
town
gate""",
"""foot
back
house
road
/
behind
brick""",
"""thing
to
thing
make
hand
/
do""",
"""grain
field
pellet
plant
hoe
plows
/""",
"""great
sickle
plows
/
field
mighty
(tills)""",
"""power
/
(djed)
stability
grandfather
pillar
authority""",
"""(lord)
/
authority
master
(every)
force
/
strength
all""",
"""(ba)
god
soul
(ankh)
life
(spirit)
ka""",
"""(truth/maat)
peace
feather
content
/
heart
(satisfied)""",
"""storm
sky
fire
slope
hill
mountain""",
"""star
emerge
(great)
sky
swallow
horizon""",
"""horizon
of
quail
head
bird
sky
chick""",
"""town
sedge
(king)
town
/
city
people""",
"""basket
/
great
thing
/
big
all)
(lord""",
"""chisel
house
stone
city
brick
adze""",
"""do
make
strong
forearm
thing
/
to""",
"""flax
rope
coil
twisted
rope
of""",
"""tethering
rope
jars
vessel
ring
stone""",
"""/
thousand
deity
/
god
altar
offering
peace""",
"""force
/
strength
backbone
rib
/
power
side""",
"""underground
emerge
water
river
ripple
snake""",
"""west
heart
satisfy
horizon
/
peace
mountain""",
"""venerated
/
marrow
old
soul
(ba)
man""",
"""/
found)
(or
is
exists
opens
road
town""",
"""god
deity
/
(or
like
as
example)
/""",
"""placenta
belly
begets
gives
birth
animal
/""",
"""clump
papyrus
lake
reed
river
shelter""",
"""/
good
life
sweet
beautiful
lotus
plant""",
"""chisel
adze
stone
big
throne
/
/
seat
great""",
"""venerated
heart
father
(ba)
soul
/
hear
marrow""",
"""authority
strength
/
mighty
king
power
force
/
he
/
great""",
"""papyrus
swallow
lake
riverbank
clump
river""",
"""three
folded
/
beautiful
thing
skins
fox
cloth
good""",
"""birth
belly
animal
(ankh)
youth
/
gives
life
begets""",
"""mountain
star
horizon
sky
above""",
"""peace
with
/
milk
handle
altar
vessel
jar
basket""",
"""city
town
door
house
gate
(djed)
bolt
stability
/""",
"""mighty
/
he
(king)
king
great
sedge
authority
/
people""",
"""plows
/
field
pellet
(tills)
grain
strong
sickle""",
"""emerge
good
beautiful
/
horizon
(great)
sky
swallow""",
"""viper
horned
fear
desert
hill
snake
slope""",
"""seated
stool
mat
peace
man
/
satisfy
senet
/
board""",
"""/
/
offering
deity
god
/
mighty
great
thousand
altar
peace""",
"""scribe
/
writing
book
hand
papyrus
scroll
scribe""",
"""loaf
mouth
vessel
/
jar
of
bread
speak
eat
drink
/""",
"""/
man
marrow
become
life
old
venerated
(ankh)
youth""",
"""sweet
(ankh)
/
plant
heart
beautiful
lotus
good
life""",
"""strong
stability
(djed)
backbone
rib
side
/
power""",
"""tethering
with
of
coil
handle
hand
rope
basket
rope""",
"""ripple
water
river
underground
snake
emerge""",
"""west
slope
horizon
mountain
desert
hill""",
"""opens
exists
city
town
road
gate
/
(or
found)
is
/
town""",
"""/
/
/
to
behind
return
house
retreat
town
gate
city
back""",
"""(ba)
/
soul
mighty
/
life
god
ka
great
(spirit)
(ankh)
deity""",
"""of
hoe
strong
head
grain
/
field
pellet
ox""",
"""sky
of
bird
head
eye
sees
star""",
"""hand
leaf
/
make
book
scribe
/
to
writing
do
reed""",
"""lotus
clump
river
shelter
plant
lake
papyrus
reed""",
"""youth
animal
gives
birth
life
/
belly
begets
placenta""",
"""big
city
/
great
town
house
/
town
brick""",
"""make
/
great
good
hand
mighty
thing
do
to
/
beautiful
/""",
"""to
brick
make
do
forearm
strong
/
hand""",
"""storm
fire
sky
great
/
fear
mighty""",
"""authority
/
people
he
hear
/
king
great
listen""",
"""(upon)
on
slope
house
/
town
hill
brick
face""",
"""/
as
/
example)
force
power
god
(or
/
deity
like
strength""",
"""(satisfied)
heart
loaf
content
peace
bread
loaf
of
/
(give)
conical""",
"""jar
peace
jar
altar
vessel
/
milk
jars
rack
in""",
"""great
jars
vessel
stone
rack
in
ring""",
"""great
stroke
marker)
thing
(plural
stroke
single
/
big""",
"""(ankh)
upon
beautiful
(ba)
face
life
/
god
/
good
soul""",
"""king
listen
authority
(lord)
servant
(every)
all
hear
master
/
/""",
"""/
strong
power
force
authority
strength
great
/
mighty""",
"""mother
begets
/
youth
life
gives
father
birth""",
"""soul
(ba)
heart
(satisfied)
/
peace
life
content
(ankh)
god""",
"""sky
desert
mountain
hill
horizon
above""",
"""stability
(djed)
/
grandfather
town
pillar
great
house
/
city""",
"""stool
chisel
to
adze
/
do
mat
make
stone
/""",
"""with
in
vessel
basket
jar
milk
handle
jars
rack""",
"""pillar
/
bolt
house
(djed)
stability
grandfather
door
gate""",
"""sedge
/
(king)
(every)
authority
/
(lord)
all
master
town
king
he""",
"""quail
of
(great)
bird
chick
horizon
swallow
head
sky""",
"""servant
fox
folded
beautiful
thing
/
cloth
three
good
skins""",
"""birth
gives
placenta
begets
belly
/
side
youth
/
animal
rib""",
"""grain
/
peace
pellet
offering
/
thousand
heart
altar""",
"""plows
water
ripple
field
sickle
(tills)
road
river""",
"""hoe
road
(repeated)
hill
desert
slope
mountain
plows""",
"""lake
(great)
shelter
swallow
reed
clump
papyrus
riverbank""",
"""scroll
leaf
book
scribe
reed
papyrus
writing
hand
/""",
"""coil
of
rope
rope
all)
basket
tethering
/
hand
(lord""",
"""stone
jar
stone
ring
jars
vessel
in
rack""",
"""viper
hill
(to
desert
slope
horned
snake
hare
be)
desert""",
"""good
/
beautiful
bird
woman
sees
head
owl
seated
of""",
"""foot
town
riverbank
city
gate
road
/
town""",
"""town
city
(plural
single
/
thing
marker)
stroke
stroke
people""",
"""soul
ka
/
deity
god
(ankh)
heart
life
(spirit)
(ba)""",
"""above
mountain
west
star
sky
horizon
above""",
"""marrow
/
venerated
father
mother
heart
/
life
peace
satisfy""",
"""negation
/
deity
god
strength
mighty
force
fear
/
/
(no/not)
great""",
"""riverbank
found)
road
is
gate
(or
exists
opens
field
/""",
"""horizon
slope
sky
hill
mountain
fire
storm""",
"""horizon
beautiful
good
/
life
sky
emerge
(ankh)
swallow
(great)""",
"""gives
/
placenta
belly
(ankh)
animal
youth
life
begets
birth""",
"""(lord
thing
basket
all)
beautiful
(ankh)
good
life
/
/
god""",
"""strong
/
he
king
grandfather
strength
power
pillar
/
authority
/
force""",
"""town
behind
/
back
/
return
to
gate
retreat
road""",
"""face
on
/
/
hill
brick
(upon)
town
house
slope
brick
city""",
"""heart
plant
peace
good
beautiful
satisfy
love
lotus
sweet
/
/""",
"""eat
/
mouth
loaf
bread
/
vessel
speak
drink
jar""",
"""strong
make
stone
to
forearm
do
/
hand
brick""",
"""chisel
big
stone
mighty
throne
seat
great
adze
/
/""",
"""snake
club
fear
snake
strength
cobra
/
force""",
"""underground
lake
water
emerge
desert
snake
ripple""",
"""/
writing
me)
scribe
(i
/
hand
man
book
seated
scribe""",
"""love
woman
satisfy
plant
seated
lotus
life
peace
/
(ankh)""",
"""(king)
sedge
mighty
/
power
authority
he
king
king
/
great""",
"""deity
(give)
altar
/
(ankh)
life
offering
peace
loaf
god
conical
/""",
"""coil
rope
ripple
tethering
rope
of
lake
water
riverbank""",
"""desert
star
hill
sky
hill
mountain
horizon""",
"""/
marrow
father
soul
heart
venerated
(ba)
man
old""",
"""sky
quail
horizon
of
star
chick
bird
head""",
"""stroke
single
papyrus
/
writing
scribe
scroll
book
hand""",
"""/
(tills)
pellet
grain
plows
field
hoe
field""",
"""house
pillar
town
/
city
stability
town
(djed)
grandfather
/""",
"""heart
mother
(ankh)
soul
youth
father
(ba)
life""",
"""above
sky
mountain
slope
field
desert
hill""",
"""adze
town
/
chisel
brick
stone
cut
city""",
"""mat
/
seated
woman
(ankh)
senet
life
stool
board""",
"""/
venerated
satisfy
peace
/
heart
mother
(ba)
marrow
soul""",
"""heart
god
lotus
deity
life
plant
(ankh)
sweet
/""",
"""head
horizon
chick
quail
bird
of
star
sky""",
"""three
fox
all
thing
/
(every)
cloth
master
folded
skins
(lord)""",
"""/
/
gives
belly
youth
birth
animal
placenta
good
beautiful
begets""",
"""/
thousand
peace
god
deity
soul
offering
(ba)
/
altar""",
"""field
ripple
/
sickle
(tills)
water
pellet
grain
plows""",
"""town
city
/
(repeated)
plows
hoe
house
road
brick""",
"""shelter
(great)
sky
swallow
papyrus
reed
lake
clump""",
"""/
writing
reed
scribe
hand
scribe
leaf
scroll
papyrus""",
"""tethering
vessel
of
coil
rope
with
handle
rope
basket""",
"""rack
stone
jars
ring
stone
vessel
throne
in""",
"""fear
mountain
hill
desert
viper
hill
snake
horned""",
"""of
heart
owl
sees
bird
head
man
seated""",
"""road
town
foot
riverbank
ripple
gate
water""",
"""force
single
stroke
strength
(plural
stroke
thing
marker)
/
people""",
"""soul
satisfy
/
(ba)
life
ka
heart
(ankh)
peace
(spirit)""",
"""west
star
above
horizon
sky
mountain
hill""",
"""good
/
father
mother
venerated
/
life
(ankh)
marrow
beautiful
youth""",
"""fire
great
god
/
/
deity
storm
mighty
fear
(no/not)
negation""",
"""city
(or
road
opens
gate
/
found)
/
town
exists
is
town""",
"""sky
above
star
(great)
emerge
horizon
swallow""",
"""king
power
authority
/
force
/
strength
he
sedge
(king)""",
"""thing
/
(ankh)
life
good
all)
/
(lord
beautiful
heart
basket""",
"""behind
gate
to
retreat
house
town
/
/
city
/
return
back""",
"""on
house
brick
(upon)
stone
slope
hill
face
/""",
"""speak
milk
drink
/
mouth
eat
bread
of
loaf
/
jar""",
"""do
forearm
to
thing
great
strong
hand
mighty
/
make
/""",
"""adze
town
town
stone
chisel
city
/
house
brick""",
"""/
hill
desert
force
strength
club
cobra
fear
snake""",
"""horizon
emerge
water
underground
snake
ripple
lake""",
"""(i
seated
book
papyrus
me)
/
man
scroll
scribe""",
"""love
lotus
satisfy
sweet
peace
plant
seated
woman
/""",
"""/
authority
(king)
/
great
he
king
power
mighty
sedge""",
"""deity
offering
peace
/
altar
conical
life
(give)
god
(ankh)
/
loaf""",
"""city
of
road
town
coil
rope
tethering
riverbank
/
rope""",
"""man
marrow
venerated
father
soul
(ba)
ka
(spirit)
old
/""",
"""field
plant
field
plows
/
(tills)
grain
pellet
hoe""",
"""great
mighty
/
stability
city
(djed)
/
pillar
grandfather
/
town
house""",
"""birth
heart
life
father
(ankh)
begets
gives
mother
/
youth""",
"""above
horizon
slope
desert
sky
mountain
hill""",
"""book
hand
/
to
writing
make
do
/
papyrus
scribe
scroll""",
"""fire
sky
mountain
mighty
storm
hill
/
slope
great""",
"""(ba)
(ankh)
/
/
deity
god
/
upon
face
soul
life
beautiful
good""",
"""/
king
servant
/
authority
(every)
hear
all
/
master
he
listen
(lord)""",
"""grandfather
/
pillar
strength
authority
/
stability
power
strong
(djed)
force""",
"""horizon
hill
above
star
mountain
sky
desert""",
"""head
above
quail
sky
chick
bird
horizon
of
star""",
"""/
town
house
brick
city
stone
adze""",
"""power
/
(every)
master
(lord)
servant
authority
all""",
"""thing
good
beautiful
/
(lord
basket
(ankh)
/
all)
life""",
"""peace
conical
loaf
(give)
satisfy
heart
/
bread""",
"""/
town
gate
door
house
town
city
bolt""",
"""eye
star
sky
horizon
sees
sky""",
"""father
beautiful
love
/
heart
youth
good""",
"""pellet
plows
/
field
(tills)
field
grain
hoe""",
"""stone
brick
make
/
do
strong
forearm
to""",
"""god
(spirit)
heart
deity
ka
(ankh)
(ba)
soul
life
/""",
"""make
thing
/
stone
do
throne
hand
to""",
"""owl
snake
sees
bird
emerge
head
of""",
"""strength
/
power
/
authority
sedge
he
king
force
(king)""",
"""/
fear
/
great
god
mighty
horned
deity
snake
viper""",
"""vessel
jar
offering
milk
jar
/
altar
peace""",
"""ripple
clump
shelter
reed
papyrus
water
lake""",
"""(ankh)
soul
sweet
heart
(ba)
life
lotus
plant""",
"""gives
good
/
father
youth
begets
birth
mother
/
beautiful""",
"""jar
speak
bread
mouth
eat
drink
vessel
/
/""",
"""venerated
man
heart
old
peace
satisfy
/
/
marrow""",
"""road
/
city
opens
/
is
found)
(or
town
exists
gate""",
"""papyrus
scribe
scroll
hand
book
writing
/
scribe""",
"""/
listen
he
king
hear
authority
king
people
/""",
"""stability
grandfather
pillar
authority
/
(djed)
/
strength
power
force""",
"""sky
mountain
(great)
quail
swallow
chick
above""",
"""reed
shelter
reed
lake
ripple
leaf
water
river""",
"""jars
stone
in
ring
vessel
rack
stone""",
"""(truth/maat)
hear
scribe
(ba)
feather
soul
heart
listen
/""",
"""love
lotus
sweet
plant
woman
life
(ankh)
seated""",
"""man
house
/
seated
board
mat
stool
senet""",
"""(tills)
field
plant
grain
plows
pellet
sickle
/""",
"""backbone
/
grandfather
pillar
rib
side
strong
(djed)
stability
/""",
"""sky
hill
star
mountain
above
desert
horizon""",
"""ripple
hill
snake
desert
slope
water
emerge""",
"""(spirit)
emerge
soul
(ba)
star
horizon
ka
sky""",
"""/
/
house
town
pillar
grandfather
(djed)
stability
city
stone""",
"""fear
mighty
great
/
fire
storm
deity
/
sky
god""",
"""/
authority
king
people
force
strength
power
he
/""",
"""/
coil
do
of
to
tethering
make
rope
rope
hand""",
"""thousand
offering
altar
jar
bread
milk
/
peace""",
"""/
to
retreat
/
town
behind
back
gate
return""",
"""lake
ripple
emerge
snake
desert
hill
water
underground""",
"""mother
(ankh)
marrow
venerated
life
father
/
youth""",
"""peace
milk
/
satisfy
jar
deity
jar
vessel
god
/""",
"""west
peace
satisfy
sky
/
heart
horizon
mountain""",
"""single
hand
scribe
papyrus
book
writing
/
stroke
scroll""",
"""venerated
marrow
become
/
man
life
(ankh)
youth
old""",
]

# %%
# Sentence Reconstruction with Heavy Augmentation & T5
# ===================================================

# 1. INSTALLATION
# ---------------------------------------------------
# We'll use a try-except block to ensure dependencies are installed
try:
    import transformers
    import sentence_transformers
    import evaluate
except ImportError:
    print("Installing missing dependencies...")
    import subprocess
    import sys
    subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", "transformers", "sentence-transformers", "sacrebleu", "evaluate", "torch"])
    import transformers
    import sentence_transformers
    import evaluate

import random
import pandas as pd
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
from torch.optim import AdamW
from transformers import T5Tokenizer, T5ForConditionalGeneration, get_linear_schedule_with_warmup
from sentence_transformers import SentenceTransformer, util
import textwrap

# Set seeds for reproducibility
def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)

set_seed(42)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# 2. DATA LOADING & PREPARATION
# ---------------------------------------------------

# CLEANING FUNCTION
def clean_input(text):
    # Remove newlines and excess whitespace
    text = text.replace('\n', ' ')
    text = " ".join(text.split())
    return text

# Apply cleaning
shuffled_clean = [clean_input(s) for s in shuffled_raw]
merged_clean = [clean_input(s) for s in merged_sentences]

# 3. AUGMENTATION STRATEGY
# ---------------------------------------------------

class ReconstructDataset(Dataset):
    def __init__(self, targets, tokenizer, max_len=64, mode='train', fixed_inputs=None):
        self.targets = targets
        self.tokenizer = tokenizer
        self.max_len = max_len
        self.mode = mode
        self.fixed_inputs = fixed_inputs

    def __len__(self):
        return len(self.targets)

    def __getitem__(self, idx):
        target_text = self.targets[idx]

        if self.mode == 'train':
            # Dynamic Augmentation: Shuffle the target words to create input
            words = target_text.split()
            random.shuffle(words)
            input_text = " ".join(words)
        else:
            # Use fixed input for evaluation
            input_text = self.fixed_inputs[idx]

        input_text = "reconstruct: " + input_text

        source = self.tokenizer(
            input_text,
            max_length=self.max_len,
            padding='max_length',
            truncation=True,
            return_tensors="pt"
        )

        target = self.tokenizer(
            target_text,
            max_length=self.max_len,
            padding='max_length',
            truncation=True,
            return_tensors="pt"
        )

        return {
            "input_ids": source["input_ids"].squeeze(),
            "attention_mask": source["attention_mask"].squeeze(),
            "labels": target["input_ids"].squeeze(),
            "raw_input": input_text,
            "raw_target": target_text
        }

# 4. MODEL SETUP
# ---------------------------------------------------
model_name = "t5-small"
tokenizer = T5Tokenizer.from_pretrained(model_name)
model = T5ForConditionalGeneration.from_pretrained(model_name)
model = model.to(device)

sim_model = SentenceTransformer('all-MiniLM-L6-v2')
sim_model = sim_model.to(device)

# 5. SPLITTING AND DATALOADERS
# ---------------------------------------------------
train_dataset = ReconstructDataset(merged_clean, tokenizer, mode='train')
val_dataset = ReconstructDataset(merged_clean, tokenizer, mode='val', fixed_inputs=shuffled_clean)

train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=16, shuffle=False)

# 6. TRAINING LOOP
# ---------------------------------------------------
optimizer = AdamW(model.parameters(), lr=3e-4)
epochs = 15
scheduler = get_linear_schedule_with_warmup(optimizer, num_warmup_steps=0, num_training_steps=len(train_loader) * epochs)

# Metric Loader
bleu_metric = evaluate.load("bleu")

print(f"\nStarting training for {epochs} epochs...")
print("-" * 65)
print(f"{'Epoch':<6} | {'Train Loss':<12} | {'Val Loss':<10} | {'BLEU':<6} | {'Cos Sim':<8}")
print("-" * 65)

import torch
import numpy as np

# Assuming model, tokenizer, train_loader, val_loader, optimizer, 
# device, and cosine_model are already defined

import torch
import pandas as pd
from sentence_transformers import util

# ... (Previous setup code assumed: model, optimizer, loaders, etc. are ready) ...

print(f"\nStarting training for {epochs} epochs...")
print("-" * 65)
print(f"{'Epoch':<6} | {'Train Loss':<12} | {'Val Loss':<10} | {'BLEU':<6} | {'Cos Sim':<8}")
print("-" * 65)

for epoch in range(epochs):
    # --- Training Phase ---
    model.train()
    total_train_loss = 0
    for batch in train_loader:
        optimizer.zero_grad()
        
        input_ids = batch["input_ids"].to(device)
        attention_mask = batch["attention_mask"].to(device)
        labels = batch["labels"].to(device)

        # Shift labels to ignore padding in loss calculation
        labels[labels == tokenizer.pad_token_id] = -100

        outputs = model(input_ids=input_ids, attention_mask=attention_mask, labels=labels)
        loss = outputs.loss
        loss.backward()
        optimizer.step()
        
        total_train_loss += loss.item()

    avg_train_loss = total_train_loss / len(train_loader)

    # --- Validation Phase ---
    model.eval()
    total_val_loss = 0
    predictions = []
    references = []
    inputs_list = []  # <--- FIX 1: Initialize the list here

    with torch.no_grad():
        for batch in val_loader:
            input_ids = batch["input_ids"].to(device)
            attention_mask = batch["attention_mask"].to(device)
            labels = batch["labels"].to(device)

            # Important: Set -100 for loss calculation
            labels_for_loss = labels.clone()
            labels_for_loss[labels_for_loss == tokenizer.pad_token_id] = -100

            outputs = model(input_ids=input_ids, attention_mask=attention_mask, labels=labels_for_loss)
            total_val_loss += outputs.loss.item()

            # Generate text for metrics
            gen_ids = model.generate(input_ids=input_ids, attention_mask=attention_mask, max_length=64)
            decoded_preds = tokenizer.batch_decode(gen_ids, skip_special_tokens=True)
            
            # Ensure labels passed to decode do not contain -100
            clean_labels = torch.where(labels != -100, labels, torch.tensor(tokenizer.pad_token_id).to(device))
            decoded_labels = tokenizer.batch_decode(clean_labels, skip_special_tokens=True)

            predictions.extend(decoded_preds)
            references.extend(decoded_labels)
            
            # <--- FIX 2: Capture the raw inputs from the batch
            inputs_list.extend(batch["raw_input"]) 

    avg_val_loss = total_val_loss / len(val_loader)

    # --- Metric Calculations ---
    bleu_results = bleu_metric.compute(predictions=predictions, references=[[r] for r in references])
    bleu_score = bleu_results["bleu"]

    # Cosine Similarity
    emb_preds = sim_model.encode(predictions, convert_to_tensor=True)
    emb_labels = sim_model.encode(references, convert_to_tensor=True)
    cos_sim = torch.nn.functional.cosine_similarity(emb_preds, emb_labels).mean().item()

    print(f"{epoch+1:<6} | {avg_train_loss:<12.4f} | {avg_val_loss:<10.4f} | {bleu_score*100:<6.2f} | {cos_sim:<8.4f}")

print("-" * 65)

# 7. FINAL RESULTS VISUALIZATION
# ---------------------------------------------------
print("\n" + "="*65)
print("FINAL RECONSTRUCTION SAMPLES")
print("="*65)

# Now inputs_list is defined and populated from the last validation epoch
df_results = pd.DataFrame({
    'Scattered Input': inputs_list,
    'Ground Truth': references,
    'Reconstructed': predictions
})

df_results['Scattered Input'] = df_results['Scattered Input'].str.replace('reconstruct: ', '')

# Calculate individual cosine similarity
final_emb_pred = sim_model.encode(df_results['Reconstructed'].tolist())
final_emb_ref = sim_model.encode(df_results['Ground Truth'].tolist())
sims = [util.cos_sim(a, b).item() for a, b in zip(final_emb_pred, final_emb_ref)]
df_results['CosSim'] = sims

sample_df = df_results.sample(min(10, len(df_results)))
for index, row in sample_df.iterrows():
    print(f"INPUT:  {row['Scattered Input']}")
    print(f"TRUTH:  {row['Ground Truth']}")
    print(f"MODEL:  {row['Reconstructed']}")
    print(f"SIM:    {row['CosSim']:.4f}")
    print("-" * 40)

# Save results
df_results.to_csv("reconstruction_results.csv", index=False)
print("\nFull results saved to 'reconstruction_results.csv'")

df_results = pd.DataFrame({
    'Scattered Input': inputs_list,
    'Ground Truth': references,
    'Reconstructed': predictions
})

df_results['Scattered Input'] = df_results['Scattered Input'].str.replace('reconstruct: ', '')

# Calculate individual cosine similarity
final_emb_pred = sim_model.encode(df_results['Reconstructed'].tolist())
final_emb_ref = sim_model.encode(df_results['Ground Truth'].tolist())
sims = [util.cos_sim(a, b).item() for a, b in zip(final_emb_pred, final_emb_ref)]
df_results['CosSim'] = sims

sample_df = df_results.sample(min(10, len(df_results)))
for index, row in sample_df.iterrows():
    print(f"INPUT:  {row['Scattered Input']}")
    print(f"TRUTH:  {row['Ground Truth']}")
    print(f"MODEL:  {row['Reconstructed']}")
    print(f"SIM:    {row['CosSim']:.4f}")
    print("-" * 40)

df_results.to_csv("reconstruction_results.csv", index=False)
print("\nFull results saved to 'reconstruction_results.csv'")
# Out:
# Using device: cuda
#
# Starting training for 15 epochs...
# -----------------------------------------------------------------
# Epoch  | Train Loss   | Val Loss   | BLEU   | Cos Sim
# -----------------------------------------------------------------
#
# Starting training for 15 epochs...
# -----------------------------------------------------------------
# Epoch  | Train Loss   | Val Loss   | BLEU   | Cos Sim
# -----------------------------------------------------------------
# 1      | 2.1954       | 0.9999     | 23.43  | 0.9024
# 2      | 1.3676       | 0.6499     | 33.65  | 0.9301
# 3      | 1.0260       | 0.4698     | 44.46  | 0.9412
# 4      | 0.8062       | 0.3338     | 58.24  | 0.9566
# 5      | 0.6422       | 0.2484     | 69.72  | 0.9618
# 6      | 0.5125       | 0.1931     | 75.09  | 0.9772
# 7      | 0.4317       | 0.1542     | 78.93  | 0.9793
# 8      | 0.3804       | 0.1167     | 82.62  | 0.9841
# 9      | 0.3370       | 0.1077     | 83.56  | 0.9858
# 10     | 0.2995       | 0.0982     | 85.43  | 0.9876
# 11     | 0.2760       | 0.0786     | 88.27  | 0.9900
# 12     | 0.2476       | 0.0687     | 89.68  | 0.9913
# 13     | 0.2300       | 0.0561     | 90.31  | 0.9924
# 14     | 0.2017       | 0.0502     | 92.05  | 0.9945
# 15     | 0.1819       | 0.0504     | 92.43  | 0.9946
# -----------------------------------------------------------------
#
# =================================================================
# FINAL RECONSTRUCTION SAMPLES
# =================================================================
# INPUT:  gives good / father youth begets birth mother / beautiful
# TRUTH:  mother father gives birth / begets beautiful / good youth
# MODEL:  father mother gives birth / begets beautiful / good youth
# SIM:    0.9963
# ----------------------------------------
# INPUT:  people life god great gives
# TRUTH:  great god gives life people
# MODEL:  great god gives life people
# SIM:    1.0000
# ----------------------------------------
# INPUT:  sees town great city king
# TRUTH:  great king sees city town
# MODEL:  great king sees city town
# SIM:    1.0000
# ----------------------------------------
# INPUT:  watches people god riverbank
# TRUTH:  god watches riverbank people
# MODEL:  god watches riverbank people
# SIM:    1.0000
# ----------------------------------------
# INPUT:  sees great town god every
# TRUTH:  every town sees great god
# MODEL:  every town sees great god
# SIM:    1.0000
# ----------------------------------------
# INPUT:  hears voice man god
# TRUTH:  god hears voice man
# MODEL:  god hears voice man
# SIM:    1.0000
# ----------------------------------------
# INPUT:  (spirit) emerge soul (ba) star horizon ka sky
# TRUTH:  soul (ba) ka (spirit) emerge horizon sky star
# MODEL:  soul (ba) emerge horizon sky star
# SIM:    0.9366
# ----------------------------------------
# INPUT:  road town foot riverbank ripple gate water
# TRUTH:  foot road town gate riverbank water ripple
# MODEL:  foot road town gate riverbank water ripple
# SIM:    1.0000
# ----------------------------------------
# INPUT:  travel west people road
# TRUTH:  people travel road west
# MODEL:  people travel road west
# SIM:    1.0000
# ----------------------------------------
# INPUT:  god gives people life
# TRUTH:  god gives life people
# MODEL:  god gives life people
# SIM:    1.0000
# ----------------------------------------
#
# Full results saved to 'reconstruction_results.csv'
# INPUT:  mighty great authority (king) / sedge power
# TRUTH:  sedge (king) authority great / mighty power
# MODEL:  sedge (king) authority great / mighty power
# SIM:    1.0000
# ----------------------------------------
# INPUT:  woman sweet speaks words
# TRUTH:  woman speaks sweet words
# MODEL:  woman speaks sweet words
# SIM:    1.0000
# ----------------------------------------
# INPUT:  / town house brick city stone adze
# TRUTH:  adze stone brick house city / town
# MODEL:  adze stone brick house city / town
# SIM:    1.0000
# ----------------------------------------
# INPUT:  voice man hears god
# TRUTH:  man hears god voice
# MODEL:  god hears voice man
# SIM:    0.8993
# ----------------------------------------
# INPUT:  town behind / back / return to gate retreat road
# TRUTH:  to return / retreat behind / back gate town road
# MODEL:  to return / retreat behind / back gate town road
# SIM:    1.0000
# ----------------------------------------
# INPUT:  / / / to behind return house retreat town gate city back
# TRUTH:  to return / retreat behind / back gate city / town house
# MODEL:  to return / retreat behind / back gate city / town
# SIM:    0.9658
# ----------------------------------------
# INPUT:  love woman satisfy plant seated lotus life peace / (ankh)
# TRUTH:  seated woman love lotus plant peace / satisfy life (ankh)
# MODEL:  seated woman love lotus plant peace / satisfy life (ankh)
# SIM:    1.0000
# ----------------------------------------
# INPUT:  above sky mountain slope field desert hill
# TRUTH:  sky above mountain desert hill slope field
# MODEL:  sky above mountain desert hill slope field
# SIM:    1.0000
# ----------------------------------------
# INPUT:  hears voice man god
# TRUTH:  god hears voice man
# MODEL:  god hears voice man
# SIM:    1.0000
# ----------------------------------------
# INPUT:  / strong power force authority strength great / mighty
# TRUTH:  authority power great / mighty strength / force strong
# MODEL:  authority power great / mighty strength / force strong
# SIM:    1.0000
# ----------------------------------------
#
# Full results saved to 'reconstruction_results.csv'
